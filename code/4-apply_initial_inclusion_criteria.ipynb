# %%
import pandas as pd
import numpy as np
import pickle
import datetime

# %%
# sets args
cmc_asset_universe_fp = "../data/raw/cmc_asset_universe.pkl"
cmc_cw_fp = "../data/raw/cmc_cw.pkl"
cmc_panel_fp = "../data/raw/cmc_price_volume_mcap_panel.pkl"
cg_cw_fp = "../data/raw/coingecko_cmc_cw.pkl"
cg_panel_fp = "../data/raw/coingecko_price_volume_mcap_panel.pkl"
cm_cw_fp = "../data/raw/coinmetrics_cmc_cw.pkl"
cm_asset_info_fp = '../data/raw/coinmetrics_assets_first_tradable.pkl'
cm_panel_fp = "../data/raw/coinmetrics_initial_panel.pkl"

# import data
with open(cmc_asset_universe_fp, 'rb') as f:
    cmc_asset_universe_dict = pickle.load(f)
cmc_cw_df =  pd.read_pickle(cmc_cw_fp)
cmc_panel_df = pd.read_pickle(cmc_panel_fp)
cg_cw_df =  pd.read_pickle(cg_cw_fp)
cg_panel_df = pd.read_pickle(cg_panel_fp)
cm_cw_df = pd.read_pickle(cm_cw_fp)
cm_asset_df = pd.read_pickle(cm_asset_info_fp)
cm_panel_df = pd.read_pickle(cm_panel_fp)

# %%
# TODO FORM SINGLE PANEL

# clean cws and panels before merge
cm_cw_df = cm_cw_df[~cm_cw_df.asset_cm.isin(['xno'])]
cm_cw_df = cm_cw_df[~cm_cw_df.asset_cmc.isin(['aave-old'])]
cm_cw_df = cm_cw_df.rename(columns = {'asset_cmc': 'slug_cmc'})
cg_cw_df = cg_cw_df[~cg_cw_df.asset_cmc.isin(['cronos', 'aave-old', 'yearn-finance-ii'])]
cg_cw_df = cg_cw_df.rename(columns={'asset_cmc': 'slug_cmc'})
cmc_panel_df['date'] = cmc_panel_df['date'].dt.date
assert type(cg_panel_df.date.values[0]) == datetime.date
cm_panel_df['time'] = pd.to_datetime(cm_panel_df['time']).dt.date
cm_panel_df = cm_panel_df.rename(columns={'asset': 'asset_cm', 'time': 'date'})
cm_asset_df = cm_asset_df.rename(columns={'asset': 'asset_cm'})

# merge panels togethers
panel_df = cmc_panel_df.merge(cg_cw_df,
                              on='slug_cmc',
                              how='left',
                              validate='many_to_one')
assert cmc_panel_df.shape[0]==panel_df.shape[0]
panel_df = panel_df.merge(cg_panel_df, on=['date', 'asset_gecko'], how='outer', validate='many_to_one')
panel_df = panel_df.merge(cm_cw_df[~cm_cw_df.slug_cmc.isnull()], on='slug_cmc', how='left', validate='many_to_one')
panel_df = panel_df.merge(cm_panel_df, on=['date', 'asset_cm'], how='outer', validate='many_to_one')

# cut down to window of interest
panel_df = panel_df[panel_df.date.apply(lambda x: x.year) >=2015]

# subset to assets with tradable market on coinmetrics and the dates after it is first tradable
panel_df = panel_df[panel_df.asset_cm.isin(cm_asset_df.asset_cm.values)].copy()
assets = list(np.unique(panel_df.asset_cm.values))
for asset in assets:
    date_first_tradable = cm_asset_df[cm_asset_df.asset_cm==asset].date_first_tradable.values[0]
    date_first_tradable = datetime.datetime.strptime(date_first_tradable, '%Y-%m-%d').date()
    rows_before = panel_df.shape[0]
    panel_df = panel_df[~((panel_df.asset_cm==asset) & (panel_df.date<date_first_tradable))]
    if rows_before != panel_df.shape[0]:
        print(f"For {asset} we lost {(rows_before - panel_df.shape[0])} rows.")
# Out:
# For aac we lost 1837 rows.
# For aave we lost 11 rows.
# For abbc we lost 1554 rows.
# For abt we lost 1605 rows.
# For ach we lost 488 rows.
# For act we lost 531 rows.
# For ada we lost 1251 rows.
# For ads we lost 1592 rows.
# For ae we lost 252 rows.
# For aergo we lost 674 rows.
# For agi we lost 137 rows.
# For aioz we lost 339 rows.
# For akro we lost 472 rows.
# For akt we lost 742 rows.
# For albt we lost 188 rows.
# For aleph we lost 713 rows.
# For algo we lost 819 rows.
# For alice we lost 198 rows.
# For alpaca we lost 158 rows.
# For amb we lost 18 rows.
# For amp we lost 438 rows.
# For anc we lost 358 rows.
# For ankr we lost 139 rows.
# For ant we lost 1183 rows.
# For any we lost 474 rows.
# For ape we lost 7 rows.
# For api3 we lost 452 rows.
# For apx we lost 615 rows.
# For aqt we lost 582 rows.
# For ar we lost 352 rows.
# For ardr we lost 662 rows.
# For ark we lost 224 rows.
# For arpa we lost 112 rows.
# For arrr we lost 762 rows.
# For asm we lost 444 rows.
# For astr we lost 93 rows.
# For atlas we lost 267 rows.
# For atom we lost 1037 rows.
# For atp we lost 211 rows.
# For avax we lost 388 rows.
# For avt we lost 91 rows.
# For axs we lost 275 rows.
# For baby we lost 449 rows.
# For badger we lost 86 rows.
# For bal we lost 42 rows.
# For basic we lost 562 rows.
# For bat we lost 165 rows.
# For bax we lost 894 rows.
# For bch we lost 856 rows.
# For bcv we lost 224 rows.
# For beam we lost 247 rows.
# For best we lost 509 rows.
# For bft we lost 22 rows.
# For bht we lost 291 rows.
# For bico we lost 8 rows.
# For bifi_beef we lost 161 rows.
# For bit we lost 292 rows.
# For bix we lost 446 rows.
# For blok we lost 28 rows.
# For bnb we lost 1187 rows.
# For bnt we lost 128 rows.
# For boa we lost 550 rows.
# For bond we lost 252 rows.
# For bora we lost 1108 rows.
# For bos we lost 888 rows.
# For boson we lost 599 rows.
# For bot we lost 565 rows.
# For brg we lost 159 rows.
# For bsv we lost 7 rows.
# For bsw we lost 261 rows.
# For btg we lost 1 rows.
# For btm we lost 584 rows.
# For btmx we lost 290 rows.
# For bts we lost 1055 rows.
# For bttc we lost 132 rows.
# For busd we lost 522 rows.
# For bzrx we lost 46 rows.
# For cake we lost 210 rows.
# For capp we lost 986 rows.
# For cdt we lost 99 rows.
# For ceek we lost 1396 rows.
# For cel we lost 650 rows.
# For celo we lost 228 rows.
# For cfg we lost 288 rows.
# For cfx we lost 138 rows.
# For chess we lost 93 rows.
# For chr we lost 345 rows.
# For chsb we lost 1294 rows.
# For chz we lost 67 rows.
# For ckb we lost 435 rows.
# For cloak we lost 1203 rows.
# For clv we lost 12 rows.
# For cnd we lost 103 rows.
# For comp we lost 6 rows.
# For core we lost 856 rows.
# For cos we lost 44 rows.
# For coti we lost 267 rows.
# For coval we lost 2056 rows.
# For cqt we lost 496 rows.
# For cream we lost 43 rows.
# For cro we lost 1054 rows.
# For crpt we lost 1521 rows.
# For crts we lost 276 rows.
# For cru we lost 344 rows.
# For crv we lost 1 rows.
# For cspr we lost 408 rows.
# For ctc we lost 893 rows.
# For ctxc we lost 585 rows.
# For cusd we lost 608 rows.
# For cvc we lost 315 rows.
# For cvt we lost 596 rows.
# For cvx we lost 203 rows.
# For dac we lost 214 rows.
# For dag we lost 652 rows.
# For dao we lost 415 rows.
# For dash we lost 1547 rows.
# For data we lost 217 rows.
# For dawn we lost 314 rows.
# For dbc we lost 442 rows.
# For dcr we lost 987 rows.
# For ddx we lost 251 rows.
# For dego we lost 174 rows.
# For dep we lost 810 rows.
# For derc we lost 453 rows.
# For dero we lost 848 rows.
# For deso we lost 181 rows.
# For dexe we lost 106 rows.
# For dfa we lost 22 rows.
# For dfi we lost 752 rows.
# For dgb we lost 1999 rows.
# For dgd we lost 588 rows.
# For dgtx we lost 771 rows.
# For dia we lost 29 rows.
# For dice we lost 1227 rows.
# For divi we lost 962 rows.
# For dka we lost 44 rows.
# For dmd we lost 2888 rows.
# For dnt we lost 73 rows.
# For dodo we lost 142 rows.
# For doge we lost 2224 rows.
# For dos we lost 508 rows.
# For dot we lost 525 rows.
# For dpi we lost 561 rows.
# For dpr we lost 215 rows.
# For drgn we lost 333 rows.
# For dsla we lost 399 rows.
# For dta we lost 171 rows.
# For dusk we lost 11 rows.
# For dx we lost 602 rows.
# For edg we lost 1691 rows.
# For egt we lost 379 rows.
# For ekt we lost 415 rows.
# For ela we lost 1601 rows.
# For eng we lost 68 rows.
# For enj we lost 218 rows.
# For eos we lost 1484 rows.
# For eps we lost 8 rows.
# For erg we lost 1878 rows.
# For ersdl we lost 223 rows.
# For esd we lost 49 rows.
# For etc we lost 686 rows.
# For ethw we lost 14 rows.
# For etn we lost 498 rows.
# For eurs we lost 936 rows.
# For ever we lost 585 rows.
# For evx we lost 16 rows.
# For exe we lost 142 rows.
# For farm we lost 342 rows.
# For fida we lost 281 rows.
# For firo we lost 1571 rows.
# For flow we lost 184 rows.
# For flux we lost 210 rows.
# For forth we lost 2 rows.
# For frax we lost 463 rows.
# For frm we lost 517 rows.
# For fsn we lost 118 rows.
# For ftm we lost 1088 rows.
# For ftt we lost 142 rows.
# For fuel we lost 24 rows.
# For fun we lost 1692 rows.
# For fx we lost 895 rows.
# For fxc we lost 412 rows.
# For fxs we lost 57 rows.
# For gala we lost 476 rows.
# For gas we lost 30 rows.
# For ghst we lost 84 rows.
# For glm we lost 1483 rows.
# For glmr we lost 51 rows.
# For gno we lost 1582 rows.
# For gnx we lost 451 rows.
# For gods we lost 40 rows.
# For grin we lost 428 rows.
# For grs we lost 1189 rows.
# For gt we lost 1056 rows.
# For gtc we lost 15 rows.
# For gvt we lost 1 rows.
# For hbar we lost 12 rows.
# For hc_hypercash we lost 364 rows.
# For hedg we lost 582 rows.
# For hegic we lost 72 rows.
# For hero we lost 482 rows.
# For hex we lost 708 rows.
# For hive we lost 32 rows.
# For hnt we lost 37 rows.
# For hot_holo we lost 294 rows.
# For hot_hydroprotocol we lost 173 rows.
# For hpb we lost 814 rows.
# For hpt we lost 42 rows.
# For ht we lost 1010 rows.
# For htr we lost 760 rows.
# For hum we lost 880 rows.
# For hxro we lost 621 rows.
# For icn we lost 388 rows.
# For icp we lost 1 rows.
# For icx we lost 85 rows.
# For id we lost 389 rows.
# For idex we lost 1333 rows.
# For idia we lost 68 rows.
# For ilv we lost 175 rows.
# For imx we lost 146 rows.
# For inv we lost 309 rows.
# For iotx we lost 7 rows.
# For iq we lost 706 rows.
# For iris we lost 460 rows.
# For itc we lost 457 rows.
# For jasmy we lost 283 rows.
# For joe we lost 121 rows.
# For jst we lost 96 rows.
# For jup we lost 1906 rows.
# For kai we lost 640 rows.
# For kan we lost 323 rows.
# For kar we lost 43 rows.
# For kcash we lost 426 rows.
# For kcs we lost 1225 rows.
# For kda we lost 649 rows.
# For keep we lost 400 rows.
# For kilt we lost 26 rows.
# For kin we lost 1245 rows.
# For klay we lost 478 rows.
# For klv we lost 680 rows.
# For kmd we lost 275 rows.
# For knc we lost 1681 rows.
# For kp3r we lost 6 rows.
# For krl we lost 1146 rows.
# For ksm we lost 645 rows.
# For lamb we lost 72 rows.
# For lcx we lost 774 rows.
# For ldo we lost 489 rows.
# For lina we lost 483 rows.
# For link we lost 1073 rows.
# For lon we lost 419 rows.
# For loom we lost 49 rows.
# For lpt we lost 891 rows.
# For lqty we lost 691 rows.
# For lrc we lost 1589 rows.
# For lsk we lost 595 rows.
# For ltc we lost 1077 rows.
# For lun we lost 241 rows.
# For luna we lost 599 rows.
# For lusd we lost 336 rows.
# For lxt we lost 225 rows.
# For lyxe we lost 86 rows.
# For man we lost 194 rows.
# For mana we lost 1570 rows.
# For math we lost 761 rows.
# For matic we lost 789 rows.
# For mbl we lost 290 rows.
# For mbox we lost 133 rows.
# For mc we lost 85 rows.
# For mco we lost 175 rows.
# For mda we lost 23 rows.
# For mdx we lost 116 rows.
# For mer we lost 1513 rows.
# For meta we lost 541 rows.
# For metis we lost 409 rows.
# For mgo we lost 481 rows.
# For mhc we lost 406 rows.
# For mina we lost 109 rows.
# For miota we lost 168 rows.
# For mir we lost 82 rows.
# For mith we lost 236 rows.
# For mkr we lost 993 rows.
# For mln we lost 1594 rows.
# For mod we lost 11 rows.
# For mof we lost 670 rows.
# For mona we lost 2734 rows.
# For movr we lost 72 rows.
# For mpl we lost 265 rows.
# For mth we lost 36 rows.
# For mvl we lost 1026 rows.
# For mx we lost 262 rows.
# For mxc we lost 1467 rows.
# For nano we lost 318 rows.
# For nav we lost 1091 rows.
# For nebl we lost 100 rows.
# For neo we lost 493 rows.
# For nest we lost 741 rows.
# For new we lost 15 rows.
# For nexo we lost 1459 rows.
# For nft we lost 19 rows.
# For nftx we lost 110 rows.
# For ngc we lost 1438 rows.
# For nim we lost 616 rows.
# For nkn we lost 501 rows.
# For nmr we lost 1150 rows.
# For nrg we lost 658 rows.
# For nu we lost 367 rows.
# For nuls we lost 14 rows.
# For nwc we lost 287 rows.
# For nxs we lost 1226 rows.
# For nxt we lost 1797 rows.
# For oax we lost 124 rows.
# For ocean we lost 397 rows.
# For ocn we lost 415 rows.
# For okb we lost 48 rows.
# For om we lost 202 rows.
# For omg we lost 628 rows.
# For omi we lost 167 rows.
# For omni we lost 1398 rows.
# For one_harmony we lost 468 rows.
# For ong_ontologygas we lost 174 rows.
# For orbs we lost 730 rows.
# For orn we lost 76 rows.
# For osmo we lost 388 rows.
# For oxen we lost 820 rows.
# For oxt we lost 279 rows.
# For oxy we lost 52 rows.
# For pai we lost 1 rows.
# For paid we lost 365 rows.
# For pax we lost 181 rows.
# For pcx we lost 603 rows.
# For people we lost 83 rows.
# For perp we lost 187 rows.
# For pha we lost 165 rows.
# For phx we lost 291 rows.
# For pivx we lost 710 rows.
# For pla we lost 399 rows.
# For plu we lost 1535 rows.
# For poe we lost 79 rows.
# For poly we lost 45 rows.
# For pond we lost 78 rows.
# For powr we lost 6 rows.
# For ppt we lost 141 rows.
# For pre we lost 849 rows.
# For pro we lost 1645 rows.
# For prom we lost 498 rows.
# For prq we lost 670 rows.
# For pundix we lost 1525 rows.
# For pyr we lost 220 rows.
# For qash we lost 23 rows.
# For qi we lost 269 rows.
# For qkc we lost 1 rows.
# For qnt we lost 1084 rows.
# For qrdo we lost 56 rows.
# For qtum we lost 295 rows.
# For quick we lost 148 rows.
# For raca we lost 222 rows.
# For rad we lost 222 rows.
# For ramp we lost 152 rows.
# For rare we lost 54 rows.
# For rari we lost 450 rows.
# For rbn we lost 62 rows.
# For rbtc we lost 100 rows.
# For rcn_ripiocreditnetwork we lost 13 rows.
# For rdn we lost 1 rows.
# For reef we lost 304 rows.
# For ren we lost 288 rows.
# For rep we lost 937 rows.
# For req we lost 7 rows.
# For rev we lost 883 rows.
# For rfox we lost 148 rows.
# For rgt we lost 335 rows.
# For rif we lost 722 rows.
# For rlc we lost 267 rows.
# For rly we lost 534 rows.
# For rmrk we lost 37 rows.
# For rndr we lost 254 rows.
# For rnt we lost 678 rows.
# For rook we lost 89 rows.
# For rose we lost 412 rows.
# For rsr we lost 459 rows.
# For ruff we lost 410 rows.
# For rune we lost 712 rows.
# For rvn we lost 216 rows.
# For salt we lost 1 rows.
# For sand we lost 476 rows.
# For sc we lost 1023 rows.
# For sdn we lost 427 rows.
# For seele we lost 287 rows.
# For sero we lost 472 rows.
# For sfi we lost 145 rows.
# For sfund we lost 415 rows.
# For shft we lost 345 rows.
# For shib we lost 433 rows.
# For slp we lost 513 rows.
# For slv we lost 566 rows.
# For snc we lost 611 rows.
# For sngls we lost 351 rows.
# For snm we lost 100 rows.
# For snt we lost 116 rows.
# For snx we lost 847 rows.
# For soc we lost 412 rows.
# For sol we lost 511 rows.
# For solo we lost 866 rows.
# For solve we lost 423 rows.
# For sos we lost 7 rows.
# For sov we lost 139 rows.
# For spa we lost 574 rows.
# For spell we lost 177 rows.
# For srk we lost 671 rows.
# For srm we lost 31 rows.
# For srn we lost 442 rows.
# For stake we lost 336 rows.
# For starl we lost 352 rows.
# For steem we lost 654 rows.
# For stmx we lost 903 rows.
# For storj we lost 124 rows.
# For strax we lost 1559 rows.
# For strk we lost 42 rows.
# For strong we lost 216 rows.
# For sub we lost 15 rows.
# For suku we lost 234 rows.
# For sun we lost 8 rows.
# For super we lost 30 rows.
# For susd we lost 875 rows.
# For sushi we lost 371 rows.
# For swap we lost 697 rows.
# For sxp we lost 368 rows.
# For syn we lost 514 rows.
# For sys we lost 1182 rows.
# For t we lost 15 rows.
# For tct we lost 740 rows.
# For tel we lost 808 rows.
# For tfuel we lost 64 rows.
# For theta we lost 131 rows.
# For thg we lost 94 rows.
# For tky we lost 785 rows.
# For tlm we lost 324 rows.
# For tlos we lost 784 rows.
# For tnb we lost 18 rows.
# For tnt we lost 86 rows.
# For tomo we lost 534 rows.
# For ton we lost 502 rows.
# For trac we lost 1371 rows.
# For trade we lost 533 rows.
# For trb we lost 282 rows.
# For tribe we lost 143 rows.
# For trig we lost 444 rows.
# For tru we lost 55 rows.
# For true we lost 669 rows.
# For trx we lost 720 rows.
# For tt we lost 67 rows.
# For twt we lost 181 rows.
# For ubt we lost 730 rows.
# For ugas we lost 16 rows.
# For uip we lost 414 rows.
# For uma we lost 107 rows.
# For uni we lost 386 rows.
# For uno we lost 2488 rows.
# For uqc we lost 1049 rows.
# For usdc we lost 179 rows.
# For usdk we lost 106 rows.
# For usdn we lost 202 rows.
# For usdt we lost 31 rows.
# For utk we lost 1008 rows.
# For uuu we lost 332 rows.
# For vee we lost 184 rows.
# For velo we lost 288 rows.
# For veri we lost 1077 rows.
# For vet we lost 10 rows.
# For vgx we lost 1494 rows.
# For via we lost 1131 rows.
# For vib we lost 24 rows.
# For vibe we lost 107 rows.
# For vlx we lost 958 rows.
# For vra we lost 1177 rows.
# For vtho we lost 723 rows.
# For vxv we lost 714 rows.
# For waves we lost 561 rows.
# For waxp we lost 1341 rows.
# For wemix we lost 733 rows.
# For wicc we lost 430 rows.
# For wom we lost 155 rows.
# For wpr we lost 48 rows.
# For wtc we lost 74 rows.
# For wxt we lost 407 rows.
# For xas we lost 977 rows.
# For xaut we lost 614 rows.
# For xch we lost 288 rows.
# For xdb we lost 341 rows.
# For xec we lost 34 rows.
# For xem we lost 1084 rows.
# For xhv we lost 1046 rows.
# For xlm we lost 1072 rows.
# For xmr we lost 1534 rows.
# For xmx we lost 273 rows.
# For xpr we lost 505 rows.
# For xprt we lost 160 rows.
# For xrd we lost 481 rows.
# For xrp we lost 1453 rows.
# For xsn we lost 1430 rows.
# For xtz we lost 821 rows.
# For xvg we lost 1005 rows.
# For xwg we lost 247 rows.
# For xym we lost 55 rows.
# For xyo we lost 1210 rows.
# For yfi we lost 21 rows.
# For yfl we lost 24 rows.
# For ygg we lost 58 rows.
# For you we lost 480 rows.
# For zec we lost 873 rows.
# For zel we lost 748 rows.
# For zen we lost 356 rows.
# For zil we lost 1042 rows.
# For zrx we lost 565 rows.

# %%
# CLEAN PRICE COLUMN

# drop rows where we have no price data
panel_df = panel_df[~(panel_df.ReferenceRateUSD.isnull() 
                    & panel_df.usd_per_token_cmc.isnull() 
                    & panel_df.usd_per_token_cg.isnull())]

# form the price column
panel_df['usd_per_token'] = np.nan
panel_df.loc[~panel_df.ReferenceRateUSD.isnull(), 'usd_per_token'] = panel_df['ReferenceRateUSD']
panel_df.loc[panel_df.usd_per_token.isnull(), 'usd_per_token'] = panel_df[['usd_per_token_cmc', 'usd_per_token_cg']].mean(axis=1, skipna=True)

# remove rows where the price between cmc and cg is different by more than 50%
panel_df = panel_df[~(panel_df.ReferenceRateUSD.isnull() 
                    & ~panel_df.usd_per_token_cmc.isnull() 
                    & ~panel_df.usd_per_token_cg.isnull()
                    & (np.abs((panel_df.usd_per_token_cmc-panel_df.usd_per_token_cg)/panel_df.usd_per_token_cmc) > 0.5))]

# keep just the final price
panel_df = panel_df.drop(columns=['usd_per_token_cmc', 'usd_per_token_cg', 
                     'PriceUSD', 'ReferenceRate', 'ReferenceRateUSD'], axis=1)

# convert dtype
panel_df['usd_per_token'] = panel_df.usd_per_token.astype(float)

# CLEAN MCAP COLUMN

# drop if there is no mcap data
panel_df = panel_df[~(panel_df.usd_mcap_cmc.isnull()
                    & panel_df.usd_mcap_cg.isnull()
                    & panel_df.CapMrktEstUSD.isnull())]

# set any zeros to missing
panel_df.loc[panel_df.CapMrktEstUSD==0, 'CapMrktEstUSD'] = np.nan
panel_df.loc[panel_df.usd_mcap_cg==0, 'usd_mcap_cg'] = np.nan
panel_df.loc[panel_df.usd_mcap_cmc==0, 'usd_mcap_cmc'] = np.nan

# form the mcap column
panel_df['CapMrktEstUSD'] = panel_df.CapMrktEstUSD.astype(float)
panel_df['usd_mcap'] = panel_df[['CapMrktEstUSD', 'usd_mcap_cg', 'usd_mcap_cmc']].mean(axis=1, skipna=True)
assert 0 == panel_df.usd_mcap.isnull().sum()

# drop rows where mcaps between cg and cmc are more than order of magnitude off when we are missing CM values
panel_df = panel_df[~(panel_df.CapMrktEstUSD.isnull() & ~panel_df.usd_mcap_cg.isnull() & ~panel_df.usd_mcap_cmc.isnull()
                      & (np.abs((panel_df.usd_mcap_cg - panel_df.usd_mcap_cmc)/panel_df.usd_mcap_cmc) > 10))]

# keep just the final price
panel_df = panel_df.drop(columns=['usd_mcap_cmc', 'usd_mcap_cg', 
                                  'CapMrktCurUSD', 'CapMrktEstUSD', 'CapMrktFFUSD', 'CapRealUSD'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb Cell 4 in <cell line: 41>()
#      <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=38'>39</a> panel_df['CapMrktEstUSD'] = panel_df.CapMrktEstUSD.astype(float)
#      <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=39'>40</a> panel_df['usd_mcap'] = panel_df[['CapMrktEstUSD', 'usd_mcap_cg', 'usd_mcap_cmc']].mean(axis=1, skipna=True)
# ---> <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=40'>41</a> assert 0 == panel_df.usd_mcap.isnull().sum()
#      <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=42'>43</a> # drop rows where mcaps between cg and cmc are more than order of magnitude off when we are missing CM values
#      <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=43'>44</a> panel_df = panel_df[~(panel_df.CapMrktEstUSD.isnull() & ~panel_df.usd_mcap_cg.isnull() & ~panel_df.usd_mcap_cmc.isnull()
#      <a href='vscode-notebook-cell:/home/baybutt/Dropbox/2-creations/2-crafts/4-i_research/2-research/2022-jmp/jmp/code/4-apply_initial_inclusion_criteria.ipynb#W3sZmlsZQ%3D%3D?line=44'>45</a>                       & (np.abs((panel_df.usd_mcap_cg - panel_df.usd_mcap_cmc)/panel_df.usd_mcap_cmc) > 10))]
#
# AssertionError:

# %%
# TODO come back to create the cm market cap measure using supply for where it is missing if useful

# %%
# TODO use coinapi for my volume estimate of LEGIT exchanges; maybe cross check with others.
# TODO also use it for a first date if it is earlier than coinmetrics
# TODO also use it for price and mcap if helpful

# %%
# TODO subset down to date, asset, price, mcap, and volume and other useful variables
# TODO look for continuity within asset. look at returns to see if anything crazy. look if mcap jump is way diff than price jump.
# TODO make sure ranges of values looks good
# TODO go scope old cleaning scripts to make sure i do all of that too

# %%
# TODO apply the inclusion criteria on the first on each month
# TODO write down what i am doing in the JMP
# TODO go scope five best factor model papers to ensure mine is best in class. add how i am better to my write up

# %%
# TODO manually check that the universe makes sense for maybe 6-10 of the random sampling of hte first years and 
# the last 3-6 random sampling over 2-3 years?


# TODO output the cmc, coingecko, and cm cw for this universe as well as a dictionary of the cmc ids at the start of each month

# TODO convert all the code to functions with professional documentation
