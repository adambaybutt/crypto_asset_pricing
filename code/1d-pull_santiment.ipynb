# %%
# TODO map asset universe to santiment assets
# TODO find all available metrics for these assets
# TODO manually cut down those metrics to just ones of interest to me
# TODO pull all metrics for all assets
# TODO figure out all possible macro metrics and cut down to ones of interest
# TODO pull all the macro metrics to for macro timeseries

# %%
# Import packages
import pandas as pd
import numpy as np
import requests
import time
import datetime as dt
from requests.exceptions import ConnectionError
import san
from graphql import GraphQLError
import multiprocessing

# %%
# santiment api key
fp = '../0-admin/santiment.txt'

with open(fp) as f:
    API_KEY = f.readlines()
    API_KEY = API_KEY[0].strip()

# %%
# Set up API
san.ApiConfig.api_key = API_KEY

# %%
# Test it is working
san.get("projects/all")
# Out:
#            marketSegment                     name                       slug  \
# 0     Blockchain Network                  Enecuum                    enecuum
# 1       Interoperability                   Cosmos                     cosmos
# 2              Financial                 ZeuxCoin                   zeuxcoin
# 3                 Energy                 Treelion                   treelion
# 4                Lending                     Kava                       kava
# ...                  ...                      ...                        ...
# 2463                DeFi  Synthetix [on Optimism]  o-synthetix-network-token
# 2464          Stablecoin   USD Coin [on Optimism]                 o-usd-coin
# 2465          Stablecoin     Tether [on Optimism]                   o-tether
# 2466          Stablecoin        Dai [on Optimism]     o-multi-collateral-dai
# 2467             Scaling                 Optimism          optimism-ethereum
#
#      ticker         totalSupply
# 0       ENQ       202238971.618
# 1      ATOM                   0
# 2       ZUC           750000000
# 3       TRN          1000000000
# 4      KAVA           251944719
# ...     ...                 ...
# 2463    SNX   215258834.2449152
# 2464   USDC  53609131421.414055
# 2465   USDT   69158976373.90933
# 2466    DAI    7268771320.62765
# 2467     OP          4294967296
#
# [2468 rows x 5 columns]

# %% [markdown]
# ## (1) Determine the relevant universe from the coinmarketcap data

# %%
# Pull in the cmc data
cmc_df = pd.read_csv('../3-data/raw/cmc_token_universe.csv')
cmc_mcap_df = pd.read_csv('../3-data/raw/cmc_price_vol_mcap_panel.csv')
macro_df = pd.read_csv('../3-data/raw/cmc_macro_timeseries.csv')
macro_df = macro_df[['date', 'total_market_cap']]
cmc_mcap_df = cmc_mcap_df.merge(macro_df,
                                on='date',
                                how='inner',
                                validate='many_to_one')

# %%
# Create the mcap threshold and drop tokens below mcap and and volume thresholds
cmc_mcap_df['mcap_threshold'] = cmc_mcap_df.total_market_cap * 0.0001
cmc_mcap_df = cmc_mcap_df[cmc_mcap_df.usd_mcap > cmc_mcap_df.mcap_threshold]
cmc_mcap_df = cmc_mcap_df[cmc_mcap_df.usd_volume_24h >= 100000]

# %%
# Cut down the cmc identifer df to those that pass threshold
cmc_df = cmc_df[cmc_df.cmc_id.isin(list(np.unique(cmc_mcap_df.cmc_id.values)))]

# %% [markdown]
# ## (2) Map cmc tokens to santiment token crosswalk

# %%
# Pull in santiment ids
san_ids_df = san.get("projects/all")

# %%
# Cut down to just relevant columns in each and create new dataframes
san_cw_df = san_ids_df[['name', 'slug', 'ticker']].copy()
san_cw_df = san_cw_df.rename(columns = {'slug': 'san_slug',
                                        'name': 'san_name',
                                        'ticker': 'san_ticker'})
cmc_cw_df = cmc_df[['cmc_symbol', 'name', 'cmc_slug']].copy()
cmc_cw_df = cmc_cw_df.rename(columns = {'name': 'cmc_name'})

# %%
# Merge on cmc data by slug

san_cw_df['san_slug'] = san_cw_df.san_slug.str.lower()
cmc_cw_df['cmc_slug'] = cmc_cw_df.cmc_slug.str.lower()
cw_df = cmc_cw_df.merge(san_cw_df[['san_slug']],
                        left_on='cmc_slug',
                        right_on='san_slug',
                        how='left',
                        validate='one_to_one')

# %%
# Update the dataframes with matched and unmatched
cmc_cw_df = cw_df[cw_df.san_slug.isnull()].copy()
cw_df     = cw_df[~cw_df.san_slug.isnull()].copy()
cw_df     = cw_df.reset_index(drop=True)
cmc_cw_df = cmc_cw_df.drop(columns='san_slug')
cmc_cw_df = cmc_cw_df.reset_index(drop=True)

# %%
# Add the other covariates to the matched crosswalk
cw_df = cw_df.merge(san_cw_df,
                    on='san_slug',
                    how='inner',
                    validate='one_to_one')

# %%
# Clean up the cmc side to drop duplicated symbols
cmc_cw_df = cmc_cw_df[~cmc_cw_df.cmc_slug.isin(['next', 'metacoin', 
                                                'bittup', 'bitclave', 'blockcat'])]

# %%
# Merge on cmc data by ticker
san_cw_df['san_ticker'] = san_cw_df['san_ticker'].str.upper()
cmc_cw_df['cmc_symbol'] = cmc_cw_df['cmc_symbol'].str.upper()
cw_df2 = cmc_cw_df.merge(san_cw_df,
                         left_on='cmc_symbol',
                         right_on='san_ticker',
                         how='left',
                         validate='one_to_many')

# Update the dataframes with matched and unmatched
cmc_cw_df = cw_df2[cw_df2.san_ticker.isnull()].copy()
cmc_cw_df = cmc_cw_df[['cmc_symbol', 'cmc_name', 'cmc_slug']].reset_index(drop=True)
cw_df2    = cw_df2[~cw_df2.san_ticker.isnull()].reset_index(drop=True)
cw_df2    = cw_df2[~cw_df2.san_slug.isin(['stox', 'zerobank', 
                                          'six-domain-chain', 'sdchain', 
                                          'wonderland', 'mint-club', 'public-mint'])]
cw_df     = cw_df.append(cw_df2)
cw_df     = cw_df[~cw_df.cmc_slug.isin(['nas', 'synereo', 'the-dao', 
                                        'cos', 'envion', 'cube', 
                                        'lina-network', 'compound-coin', 'soda-coin', 
                                        'metaverse-dualchain-network-architecture'])]

# %%
# Merge on cmc data by name
san_cw_df['san_name'] = san_cw_df['san_name'].str.lower()
cmc_cw_df['cmc_name'] = cmc_cw_df['cmc_name'].str.lower()
cw_df3 = cmc_cw_df.merge(san_cw_df,
                         left_on='cmc_name',
                         right_on='san_name',
                         how='left',
                         validate='one_to_many')

# Update the dataframes
cmc_cw_df = cw_df3[cw_df3.san_name.isnull()].copy()
cmc_cw_df = cmc_cw_df[['cmc_symbol', 'cmc_name', 'cmc_slug']].reset_index(drop=True)
cw_df3 = cw_df3[cw_df3.cmc_slug == 'firo'].reset_index(drop=True)
cw_df  = cw_df.append(cw_df3)
cw_df = cw_df.reset_index(drop=True)

# %%
# Fix one slug that was lower cased
cw_df.loc[cw_df.san_slug == 'btrst', 'san_slug'] = 'BTRST'

# %%
# Add back the Santiment metadata
n_b4 = cw_df.shape[0]
cw_df = cw_df.merge(san_ids_df[['marketSegment', 'slug', 'totalSupply']],
                    left_on='san_slug',
                    right_on='slug',
                    how='inner',
                    validate='one_to_one')
assert(cw_df.shape[0] == n_b4)
# Out:
# 883

# %% [markdown]
# ## (3) Find the available metrics for each asset

# %%
san_slugs_list = list(cw_df.san_slug.values)

# %%
def obtainMetricsForSlug(san_slug):
    san_slug_metrics_dict[san_slug] = san.available_metrics_for_slug(san_slug)
    time.sleep(.121)

# Initiate object to store results
manager = multiprocessing.Manager()
san_slug_metrics_dict = manager.dict()
failed_pulls_list = []

i=0
num_slugs = len(san_slugs_list)
for san_slug in san_slugs_list:
    print('Completed ' + str(np.round(i/num_slugs * 100, 2)) + '% of the slugs.')
    i += 1
    print(san_slug)

    # Initiate the call as a process
    p = multiprocessing.Process(target=obtainMetricsForSlug, args=(san_slug, ))
    p.start()

    time.sleep(2)
    # If thread is active
    if p.is_alive():
        print("api call is still running... let's kill it...")
        p.terminate()

        # Try the call again
        p = multiprocessing.Process(target=obtainMetricsForSlug, args=(san_slug, ))
        p.start()
        time.sleep(3)
        if p.is_alive():
            print('api call failed twice')
            p.terminate()

            # Try the call one last time
            p = multiprocessing.Process(target=obtainMetricsForSlug, args=(san_slug, ))
            p.start()
            time.sleep(4)
            if p.is_alive():
                print('api call failed thrice\n')
                p.terminate()
                failed_pulls_list.append(san_slug)
                continue

    # Cleanup
    p.join()
# Out:
# Completed 0.0% of the slugs.
# bitcoin
# Completed 0.11% of the slugs.
# litecoin
# Completed 0.23% of the slugs.
# namecoin
# Completed 0.34% of the slugs.
# peercoin
# Completed 0.45% of the slugs.
# novacoin
# Completed 0.57% of the slugs.
# feathercoin
# Completed 0.68% of the slugs.
# infinitecoin
# Completed 0.79% of the slugs.
# primecoin
# Completed 0.91% of the slugs.
# nxt
# Completed 1.02% of the slugs.
# unobtanium
# Completed 1.13% of the slugs.
# dogecoin
# Completed 1.25% of the slugs.
# omni
# Completed 1.36% of the slugs.
# mooncoin
# Completed 1.47% of the slugs.
# dimecoin
# Completed 1.59% of the slugs.
# vertcoin
# Completed 1.7% of the slugs.
# digibyte
# Completed 1.81% of the slugs.
# dash
# Completed 1.93% of the slugs.
# counterparty
# Completed 2.04% of the slugs.
# dnotes
# Completed 2.15% of the slugs.
# einsteinium
# Completed 2.27% of the slugs.
# eccoin
# Completed 2.38% of the slugs.
# monacoin
# Completed 2.49% of the slugs.
# faircoin
# Completed 2.6% of the slugs.
# solarcoin
# Completed 2.72% of the slugs.
# gulden
# Completed 2.83% of the slugs.
# groestlcoin
# Completed 2.94% of the slugs.
# maidsafecoin
# Completed 3.06% of the slugs.
# newyorkcoin
# Completed 3.17% of the slugs.
# monero
# Completed 3.28% of the slugs.
# cloakcoin
# Completed 3.4% of the slugs.
# bytecoin-bcn
# Completed 3.51% of the slugs.
# nav-coin
# Completed 3.62% of the slugs.
# digitalnote
# Completed 3.74% of the slugs.
# boolberry
# Completed 3.85% of the slugs.
# bitshares
# Completed 3.96% of the slugs.
# viacoin
# Completed 4.08% of the slugs.
# iocoin
# Completed 4.19% of the slugs.
# stellar
# Completed 4.3% of the slugs.
# syscoin
# Completed 4.42% of the slugs.
# emercoin
# Completed 4.53% of the slugs.
# burst
# Completed 4.64% of the slugs.
# gamecredits
# Completed 4.76% of the slugs.
# ubiq
# Completed 4.87% of the slugs.
# bitcny
# Completed 4.98% of the slugs.
# nubits
# Completed 5.1% of the slugs.
# verge
# api call is still running... let's kill it...
# Completed 5.21% of the slugs.
# blocknet
# Completed 5.32% of the slugs.
# circuits-of-value
# Completed 5.44% of the slugs.
# nexus
# Completed 5.55% of the slugs.
# tether
# Completed 5.66% of the slugs.
# gridcoin
# Completed 5.78% of the slugs.
# pura
# Completed 5.89% of the slugs.
# nem
# Completed 6.0% of the slugs.
# aeon
# Completed 6.12% of the slugs.
# ethereum
# Completed 6.23% of the slugs.
# agoras-tokens
# Completed 6.34% of the slugs.
# siacoin
# Completed 6.46% of the slugs.
# global-currency-reserve
# Completed 6.57% of the slugs.
# shift
# Completed 6.68% of the slugs.
# expanse
# Completed 6.8% of the slugs.
# factom
# Completed 6.91% of the slugs.
# augur
# Completed 7.02% of the slugs.
# validity
# Completed 7.13% of the slugs.
# salus
# Completed 7.25% of the slugs.
# decred
# Completed 7.36% of the slugs.
# pivx
# Completed 7.47% of the slugs.
# safex-token
# Completed 7.59% of the slugs.
# lisk
# Completed 7.7% of the slugs.
# digixdao
# Completed 7.81% of the slugs.
# steem
# Completed 7.93% of the slugs.
# waves
# api call is still running... let's kill it...
# Completed 8.04% of the slugs.
# ion
# Completed 8.15% of the slugs.
# steem-dollars
# Completed 8.27% of the slugs.
# ardor
# Completed 8.38% of the slugs.
# ethereum-classic
# Completed 8.49% of the slugs.
# stratis
# Completed 8.61% of the slugs.
# neo
# api call is still running... let's kill it...
# Completed 8.72% of the slugs.
# pluton
# Completed 8.83% of the slugs.
# pepe-cash
# Completed 8.95% of the slugs.
# iconomi
# Completed 9.06% of the slugs.
# singulardtv
# Completed 9.17% of the slugs.
# zcash
# Completed 9.29% of the slugs.
# zclassic
# Completed 9.4% of the slugs.
# lykke
# Completed 9.51% of the slugs.
# golem-network-tokens
# Completed 9.63% of the slugs.
# incent
# Completed 9.74% of the slugs.
# decent
# Completed 9.85% of the slugs.
# wings
# Completed 9.97% of the slugs.
# maker
# Completed 10.08% of the slugs.
# komodo
# Completed 10.19% of the slugs.
# nano
# Completed 10.31% of the slugs.
# ark
# api call is still running... let's kill it...
# Completed 10.42% of the slugs.
# mercury
# Completed 10.53% of the slugs.
# soarcoin
# Completed 10.65% of the slugs.
# edgeless
# Completed 10.76% of the slugs.
# guppy
# Completed 10.87% of the slugs.
# skycoin
# Completed 10.99% of the slugs.
# xtrabytes
# Completed 11.1% of the slugs.
# rlc
# Completed 11.21% of the slugs.
# trust
# Completed 11.33% of the slugs.
# bitcore
# Completed 11.44% of the slugs.
# lunyr
# Completed 11.55% of the slugs.
# gnosis-gno
# Completed 11.66% of the slugs.
# monolith
# Completed 11.78% of the slugs.
# humaniq
# Completed 11.89% of the slugs.
# aragon
# Completed 12.0% of the slugs.
# qtum
# Completed 12.12% of the slugs.
# basic-attention-token
# Completed 12.23% of the slugs.
# aeternity
# api call is still running... let's kill it...
# Completed 12.34% of the slugs.
# metaverse
# Completed 12.46% of the slugs.
# aidos-kuneen
# Completed 12.57% of the slugs.
# electra
# Completed 12.68% of the slugs.
# quantum-resistant-ledger
# Completed 12.8% of the slugs.
# mobilego
# Completed 12.91% of the slugs.
# iota
# Completed 13.02% of the slugs.
# mysterium
# Completed 13.14% of the slugs.
# sonm
# Completed 13.25% of the slugs.
# bancor
# Completed 13.36% of the slugs.
# numeraire
# Completed 13.48% of the slugs.
# gxchain
# Completed 13.59% of the slugs.
# atc-coin
# Completed 13.7% of the slugs.
# flash
# Completed 13.82% of the slugs.
# tenx
# Completed 13.93% of the slugs.
# status
# Completed 14.04% of the slugs.
# ergo
# Completed 14.16% of the slugs.
# eos
# Completed 14.27% of the slugs.
# adx-net
# Completed 14.38% of the slugs.
# storj
# Completed 14.5% of the slugs.
# adtoken
# Completed 14.61% of the slugs.
# crypto-com
# Completed 14.72% of the slugs.
# wagerr
# Completed 14.84% of the slugs.
# polybius
# Completed 14.95% of the slugs.
# gas
# Completed 15.06% of the slugs.
# metal
# Completed 15.18% of the slugs.
# populous
# Completed 15.29% of the slugs.
# santiment
# Completed 15.4% of the slugs.
# cvcoin
# Completed 15.52% of the slugs.
# civic
# Completed 15.63% of the slugs.
# particl
# Completed 15.74% of the slugs.
# smartcash
# api call is still running... let's kill it...
# Completed 15.86% of the slugs.
# bitcoin-cash
# Completed 15.97% of the slugs.
# pillar
# Completed 16.08% of the slugs.
# ixledger
# Completed 16.19% of the slugs.
# mothership
# Completed 16.31% of the slugs.
# oax
# Completed 16.42% of the slugs.
# district0x
# Completed 16.53% of the slugs.
# stox
# Completed 16.65% of the slugs.
# blox
# Completed 16.76% of the slugs.
# bytom
# Completed 16.87% of the slugs.
# dentacoin
# Completed 16.99% of the slugs.
# dent
# Completed 17.1% of the slugs.
# the-champcoin
# Completed 17.21% of the slugs.
# 0x
# Completed 17.33% of the slugs.
# yoyow
# Completed 17.44% of the slugs.
# hypercash
# Completed 17.55% of the slugs.
# nebulas-token
# Completed 17.67% of the slugs.
# achain
# Completed 17.78% of the slugs.
# tierion
# api call is still running... let's kill it...
# Completed 17.89% of the slugs.
# waltonchain
# Completed 18.01% of the slugs.
# primas
# Completed 18.12% of the slugs.
# loopring
# Completed 18.23% of the slugs.
# poet
# Completed 18.35% of the slugs.
# monetha
# Completed 18.46% of the slugs.
# agrello-delta
# Completed 18.57% of the slugs.
# hiveterminal-token
# Completed 18.69% of the slugs.
# moeda-loyalty-points
# Completed 18.8% of the slugs.
# neblio
# Completed 18.91% of the slugs.
# tron
# Completed 19.03% of the slugs.
# decentraland
# Completed 19.14% of the slugs.
# propy
# Completed 19.25% of the slugs.
# chainlink
# Completed 19.37% of the slugs.
# blackmoon
# Completed 19.48% of the slugs.
# vibe
# Completed 19.59% of the slugs.
# substratum
# Completed 19.71% of the slugs.
# kin
# Completed 19.82% of the slugs.
# salt
# Completed 19.93% of the slugs.
# ormeus-coin
# Completed 20.05% of the slugs.
# cardano
# Completed 20.16% of the slugs.
# tezos
# Completed 20.27% of the slugs.
# viberate
# Completed 20.39% of the slugs.
# rchain
# Completed 20.5% of the slugs.
# bridgecoin
# Completed 20.61% of the slugs.
# everex
# Completed 20.72% of the slugs.
# paypie
# Completed 20.84% of the slugs.
# hellogold
# Completed 20.95% of the slugs.
# cindicator
# Completed 21.06% of the slugs.
# enigma
# Completed 21.18% of the slugs.
# zeusshield
# Completed 21.29% of the slugs.
# airswap
# Completed 21.4% of the slugs.
# blockmason
# Completed 21.52% of the slugs.
# aion
# Completed 21.63% of the slugs.
# everus
# Completed 21.74% of the slugs.
# domraider
# Completed 21.86% of the slugs.
# request
# Completed 21.97% of the slugs.
# amber
# Completed 22.08% of the slugs.
# bitcoin-gold
# Completed 22.2% of the slugs.
# nuls
# Completed 22.31% of the slugs.
# paragon
# Completed 22.42% of the slugs.
# boscoin
# Completed 22.54% of the slugs.
# ripio-credit-network
# Completed 22.65% of the slugs.
# icon
# Completed 22.76% of the slugs.
# phoenix-global
# Completed 22.88% of the slugs.
# etherparty
# Completed 22.99% of the slugs.
# enjin-coin
# Completed 23.1% of the slugs.
# power-ledger
# Completed 23.22% of the slugs.
# revain
# Completed 23.33% of the slugs.
# electroneum
# Completed 23.44% of the slugs.
# minexcoin
# Completed 23.56% of the slugs.
# shield-xsh
# Completed 23.67% of the slugs.
# aeron
# Completed 23.78% of the slugs.
# raiden-network-token
# Completed 23.9% of the slugs.
# delphy
# Completed 24.01% of the slugs.
# decent-bet
# Completed 24.12% of the slugs.
# genesis-vision
# Completed 24.24% of the slugs.
# encrypgen
# Completed 24.35% of the slugs.
# ink
# Completed 24.46% of the slugs.
# bodhi
# Completed 24.58% of the slugs.
# quantstamp
# Completed 24.69% of the slugs.
# qash
# Completed 24.8% of the slugs.
# spankchain
# Completed 24.92% of the slugs.
# bitcoin-diamond
# Completed 25.03% of the slugs.
# blockv
# Completed 25.14% of the slugs.
# time-new-bank
# Completed 25.25% of the slugs.
# dragonchain
# Completed 25.37% of the slugs.
# presearch
# Completed 25.48% of the slugs.
# cybermiles
# Completed 25.59% of the slugs.
# iot-chain
# Completed 25.71% of the slugs.
# medishares
# Completed 25.82% of the slugs.
# ignis
# Completed 25.93% of the slugs.
# smartmesh
# Completed 26.05% of the slugs.
# playkey
# Completed 26.16% of the slugs.
# lockchain
# Completed 26.27% of the slugs.
# gifto
# Completed 26.39% of the slugs.
# genaro-network
# api call is still running... let's kill it...
# Completed 26.5% of the slugs.
# ost
# Completed 26.61% of the slugs.
# stormx
# Completed 26.73% of the slugs.
# aelf
# Completed 26.84% of the slugs.
# wax
# Completed 26.95% of the slugs.
# medibloc
# Completed 27.07% of the slugs.
# dew
# Completed 27.18% of the slugs.
# naga
# Completed 27.29% of the slugs.
# bread
# Completed 27.41% of the slugs.
# bibox-token
# Completed 27.52% of the slugs.
# sirin-labs-token
# Completed 27.63% of the slugs.
# html-coin
# Completed 27.75% of the slugs.
# deepbrain-chain
# Completed 27.86% of the slugs.
# neumark
# Completed 27.97% of the slugs.
# utrust
# Completed 28.09% of the slugs.
# qlink
# Completed 28.2% of the slugs.
# bigone-token
# Completed 28.31% of the slugs.
# lightning-bitcoin
# Completed 28.43% of the slugs.
# game
# Completed 28.54% of the slugs.
# lamden
# Completed 28.65% of the slugs.
# swftcoin
# Completed 28.77% of the slugs.
# canyacoin
# Completed 28.88% of the slugs.
# appcoins
# Completed 28.99% of the slugs.
# high-performance-blockchain
# Completed 29.11% of the slugs.
# waykichain
# Completed 29.22% of the slugs.
# zap
# Completed 29.33% of the slugs.
# tokenclub
# Completed 29.45% of the slugs.
# qunqun
# Completed 29.56% of the slugs.
# kcash
# Completed 29.67% of the slugs.
# bottos
# Completed 29.78% of the slugs.
# telcoin
# Completed 29.9% of the slugs.
# selfkey
# Completed 30.01% of the slugs.
# oneroot-network
# Completed 30.12% of the slugs.
# iostoken
# Completed 30.24% of the slugs.
# spacechain
# Completed 30.35% of the slugs.
# singularitynet
# Completed 30.46% of the slugs.
# chatcoin
# Completed 30.58% of the slugs.
# scryinfo
# Completed 30.69% of the slugs.
# mobius
# Completed 30.8% of the slugs.
# hydro-protocol
# Completed 30.92% of the slugs.
# yee
# Completed 31.03% of the slugs.
# acute-angle-cloud
# Completed 31.14% of the slugs.
# molecular-future
# Completed 31.26% of the slugs.
# trinity-network-credit
# Completed 31.37% of the slugs.
# data
# Completed 31.48% of the slugs.
# crpt
# Completed 31.6% of the slugs.
# carvertical
# Completed 31.71% of the slugs.
# educare
# Completed 31.82% of the slugs.
# unlimitedip
# Completed 31.94% of the slugs.
# truechain
# Completed 32.05% of the slugs.
# odyssey
# Completed 32.16% of the slugs.
# indahash
# Completed 32.28% of the slugs.
# origintrail
# Completed 32.39% of the slugs.
# linkeye
# api call is still running... let's kill it...
# Completed 32.5% of the slugs.
# zilliqa
# Completed 32.62% of the slugs.
# all-sports
# Completed 32.73% of the slugs.
# matrix-ai-network
# Completed 32.84% of the slugs.
# ruff
# Completed 32.96% of the slugs.
# zeepin
# Completed 33.07% of the slugs.
# cpchain
# Completed 33.18% of the slugs.
# elastos
# Completed 33.3% of the slugs.
# stk
# Completed 33.41% of the slugs.
# polymath-network
# Completed 33.52% of the slugs.
# medical-chain
# Completed 33.64% of the slugs.
# jibrel-network
# Completed 33.75% of the slugs.
# swissborg
# Completed 33.86% of the slugs.
# huobi-token
# Completed 33.98% of the slugs.
# dmarket
# Completed 34.09% of the slugs.
# bluzelle
# Completed 34.2% of the slugs.
# thekey
# Completed 34.31% of the slugs.
# datawallet
# Completed 34.43% of the slugs.
# wepower
# Completed 34.54% of the slugs.
# ucash
# Completed 34.65% of the slugs.
# universa
# Completed 34.77% of the slugs.
# alphacat
# Completed 34.88% of the slugs.
# cashaa
# Completed 34.99% of the slugs.
# fusion
# Completed 35.11% of the slugs.
# nectar
# Completed 35.22% of the slugs.
# ren
# Completed 35.33% of the slugs.
# litecoin-cash
# Completed 35.45% of the slugs.
# nucleus-vision
# Completed 35.56% of the slugs.
# arcblock
# Completed 35.67% of the slugs.
# iht-real-estate-protocol
# Completed 35.79% of the slugs.
# refereum
# Completed 35.9% of the slugs.
# lympo
# Completed 36.01% of the slugs.
# credits
# Completed 36.13% of the slugs.
# trueusd
# Completed 36.24% of the slugs.
# ontology
# Completed 36.35% of the slugs.
# datx
# Completed 36.47% of the slugs.
# tomochain
# Completed 36.58% of the slugs.
# babb
# Completed 36.69% of the slugs.
# electrifyasia
# Completed 36.81% of the slugs.
# bitcoin-private
# Completed 36.92% of the slugs.
# tokenomy
# Completed 37.03% of the slugs.
# ravencoin
# Completed 37.15% of the slugs.
# synthetix-network-token
# Completed 37.26% of the slugs.
# loom-network
# Completed 37.37% of the slugs.
# banca
# Completed 37.49% of the slugs.
# dragon-coins
# Completed 37.6% of the slugs.
# nanjcoin
# Completed 37.71% of the slugs.
# pundi-x
# api call is still running... let's kill it...
# Completed 37.83% of the slugs.
# bnktothefuture
# Completed 37.94% of the slugs.
# wanchain
# Completed 38.05% of the slugs.
# mithril
# Completed 38.17% of the slugs.
# switcheo
# Completed 38.28% of the slugs.
# tokenpay
# Completed 38.39% of the slugs.
# odem
# Completed 38.51% of the slugs.
# stakenet
# Completed 38.62% of the slugs.
# cortex
# Completed 38.73% of the slugs.
# apex
# Completed 38.84% of the slugs.
# cybervein
# Completed 38.96% of the slugs.
# sentinel
# Completed 39.07% of the slugs.
# eosdac
# Completed 39.18% of the slugs.
# u-network
# Completed 39.3% of the slugs.
# dignity
# Completed 39.41% of the slugs.
# haven-protocol
# Completed 39.52% of the slugs.
# dero
# Completed 39.64% of the slugs.
# we-own
# Completed 39.75% of the slugs.
# dock
# Completed 39.86% of the slugs.
# holo
# Completed 39.98% of the slugs.
# penta
# Completed 40.09% of the slugs.
# nexo
# Completed 40.2% of the slugs.
# daex
# Completed 40.32% of the slugs.
# hydro
# Completed 40.43% of the slugs.
# celsius
# Completed 40.54% of the slugs.
# bitcoin-interest
# Completed 40.66% of the slugs.
# crowd-machine
# Completed 40.77% of the slugs.
# fuzex
# Completed 40.88% of the slugs.
# bezant
# Completed 41.0% of the slugs.
# content-neutrality-network
# Completed 41.11% of the slugs.
# sakura-bloom
# Completed 41.22% of the slugs.
# unibright
# Completed 41.34% of the slugs.
# libra-credit
# Completed 41.45% of the slugs.
# morpheus-network
# Completed 41.56% of the slugs.
# xyo
# Completed 41.68% of the slugs.
# cryptaur
# Completed 41.79% of the slugs.
# travala
# Completed 41.9% of the slugs.
# iotex
# Completed 42.02% of the slugs.
# nkn
# Completed 42.13% of the slugs.
# zip
# Completed 42.24% of the slugs.
# phantasma
# Completed 42.36% of the slugs.
# seele
# Completed 42.47% of the slugs.
# endor-protocol
# Completed 42.58% of the slugs.
# pchain
# Completed 42.7% of the slugs.
# quarkchain
# Completed 42.81% of the slugs.
# ether-zero
# Completed 42.92% of the slugs.
# ceek-vr
# Completed 43.04% of the slugs.
# xmax
# Completed 43.15% of the slugs.
# gochain
# Completed 43.26% of the slugs.
# constellation
# Completed 43.37% of the slugs.
# aurora
# Completed 43.49% of the slugs.
# ternio
# Completed 43.6% of the slugs.
# distributed-credit-chain
# Completed 43.71% of the slugs.
# egretia
# Completed 43.83% of the slugs.
# mainframe
# Completed 43.94% of the slugs.
# gonetwork
# Completed 44.05% of the slugs.
# project-pai
# Completed 44.17% of the slugs.
# moss-coin
# Completed 44.28% of the slugs.
# susd
# Completed 44.39% of the slugs.
# everipedia
# Completed 44.51% of the slugs.
# bitkan
# Completed 44.62% of the slugs.
# hashgard
# Completed 44.73% of the slugs.
# rocket-pool
# Completed 44.85% of the slugs.
# contentbox
# Completed 44.96% of the slugs.
# proton-token
# Completed 45.07% of the slugs.
# cosmo-coin
# api call is still running... let's kill it...
# Completed 45.19% of the slugs.
# mvl
# Completed 45.3% of the slugs.
# arbitrage
# Completed 45.41% of the slugs.
# stasis-euro
# Completed 45.53% of the slugs.
# nix
# Completed 45.64% of the slugs.
# vethor-token
# Completed 45.75% of the slugs.
# bhp-coin
# Completed 45.87% of the slugs.
# zel
# Completed 45.98% of the slugs.
# you-coin
# Completed 46.09% of the slugs.
# bitcapitalvendor
# Completed 46.21% of the slugs.
# litex
# Completed 46.32% of the slugs.
# vechain
# Completed 46.43% of the slugs.
# proximax
# Completed 46.55% of the slugs.
# dxchain-token
# Completed 46.66% of the slugs.
# ubex
# Completed 46.77% of the slugs.
# hycon
# api call is still running... let's kill it...
# Completed 46.89% of the slugs.
# davinci-coin
# Completed 47.0% of the slugs.
# quant
# Completed 47.11% of the slugs.
# pumapay
# Completed 47.23% of the slugs.
# maro
# Completed 47.34% of the slugs.
# nasdacoin
# Completed 47.45% of the slugs.
# ontology-gas
# Completed 47.57% of the slugs.
# energi
# Completed 47.68% of the slugs.
# timicoin
# Completed 47.79% of the slugs.
# amo-coin
# Completed 47.9% of the slugs.
# evencoin
# Completed 48.02% of the slugs.
# gemini-dollar
# Completed 48.13% of the slugs.
# spendcoin
# Completed 48.24% of the slugs.
# robotina
# Completed 48.36% of the slugs.
# paxos-standard
# Completed 48.47% of the slugs.
# the-midas-touch-gold
# Completed 48.58% of the slugs.
# crdnetwork
# Completed 48.7% of the slugs.
# darcio-ecosystem-coin
# Completed 48.81% of the slugs.
# free-coin
# Completed 48.92% of the slugs.
# usd-coin
# Completed 49.04% of the slugs.
# metadium
# Completed 49.15% of the slugs.
# abbc-coin
# Completed 49.26% of the slugs.
# divi
# Completed 49.38% of the slugs.
# zbg-token
# Completed 49.49% of the slugs.
# box-token
# Completed 49.6% of the slugs.
# fantom
# Completed 49.72% of the slugs.
# dex
# Completed 49.83% of the slugs.
# kleros
# Completed 49.94% of the slugs.
# humanscape
# Completed 50.06% of the slugs.
# bitcoin-sv
# Completed 50.17% of the slugs.
# cwv-chain
# Completed 50.28% of the slugs.
# business-credit-alliance-chain
# Completed 50.4% of the slugs.
# ilcoin
# Completed 50.51% of the slugs.
# atlas-protocol
# api call is still running... let's kill it...
# Completed 50.62% of the slugs.
# crypto-com-coin
# Completed 50.74% of the slugs.
# aergo
# Completed 50.85% of the slugs.
# livepeer
# Completed 50.96% of the slugs.
# coinus
# Completed 51.08% of the slugs.
# lambda
# Completed 51.19% of the slugs.
# fountain
# Completed 51.3% of the slugs.
# hedgetrade
# Completed 51.42% of the slugs.
# hyperion
# Completed 51.53% of the slugs.
# beam
# Completed 51.64% of the slugs.
# v-systems
# Completed 51.76% of the slugs.
# grin
# Completed 51.87% of the slugs.
# lto-network
# Completed 51.98% of the slugs.
# wrapped-bitcoin
# Completed 52.1% of the slugs.
# bittorrent
# Completed 52.21% of the slugs.
# huobi-pool-token
# Completed 52.32% of the slugs.
# solve
# Completed 52.43% of the slugs.
# s4fe
# Completed 52.55% of the slugs.
# hxro
# Completed 52.66% of the slugs.
# metahash
# Completed 52.77% of the slugs.
# pibble
# Completed 52.89% of the slugs.
# fetch
# Completed 53.0% of the slugs.
# ankr
# Completed 53.11% of the slugs.
# cosmos
# Completed 53.23% of the slugs.
# bora
# Completed 53.34% of the slugs.
# dos-network
# Completed 53.45% of the slugs.
# flexacoin
# Completed 53.57% of the slugs.
# celer-network
# Completed 53.68% of the slugs.
# verasity
# Completed 53.79% of the slugs.
# theta-fuel
# Completed 53.91% of the slugs.
# top
# Completed 54.02% of the slugs.
# nash-exchange
# Completed 54.13% of the slugs.
# orbs
# Completed 54.25% of the slugs.
# contents-protocol
# Completed 54.36% of the slugs.
# locus-chain
# Completed 54.47% of the slugs.
# fnb-protocol
# Completed 54.59% of the slugs.
# ugas
# Completed 54.7% of the slugs.
# conun
# Completed 54.81% of the slugs.
# alpha-token
# Completed 54.93% of the slugs.
# newton
# Completed 55.04% of the slugs.
# irisnet
# Completed 55.15% of the slugs.
# function-x
# Completed 55.27% of the slugs.
# okb
# Completed 55.38% of the slugs.
# decimated
# Completed 55.49% of the slugs.
# ocean-protocol
# Completed 55.61% of the slugs.
# diamond-platform-token
# api call is still running... let's kill it...
# Completed 55.72% of the slugs.
# drep
# Completed 55.83% of the slugs.
# idex
# Completed 55.95% of the slugs.
# bqt
# Completed 56.06% of the slugs.
# thunder-token
# Completed 56.17% of the slugs.
# sparkpoint
# Completed 56.29% of the slugs.
# gny
# Completed 56.4% of the slugs.
# harmony
# Completed 56.51% of the slugs.
# carry
# Completed 56.63% of the slugs.
# pirate-chain
# Completed 56.74% of the slugs.
# unus-sed-leo
# Completed 56.85% of the slugs.
# reserve-rights
# Completed 56.96% of the slugs.
# elitium
# Completed 57.08% of the slugs.
# chromia
# Completed 57.19% of the slugs.
# origo
# Completed 57.3% of the slugs.
# coti
# Completed 57.42% of the slugs.
# zenon
# Completed 57.53% of the slugs.
# bitcoin-bep2
# Completed 57.64% of the slugs.
# liquid-apps
# Process Process-525:
# Traceback (most recent call last):
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 428, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 472, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py", line 734, in reraise
#     raise value.with_traceback(tb)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 428, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 472, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/home/baybutt/anaconda3/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# urllib3.exceptions.ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/san/graphql.py", line 14, in execute_gql
#     response = requests.post(
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/api.py", line 117, in post
#     return request('post', url, data=data, json=json, **kwargs)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/requests/adapters.py", line 501, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/baybutt/anaconda3/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/baybutt/anaconda3/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-19-dff7b38e2920>", line 2, in obtainMetricsForSlug
#     san_slug_metrics_dict[san_slug] = san.available_metrics_for_slug(san_slug)
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/san/available_metrics.py", line 22, in available_metrics_for_slug
#     return execute_gql(query_str)['projectBySlug']['availableMetrics']
#   File "/home/baybutt/anaconda3/lib/python3.8/site-packages/san/graphql.py", line 19, in execute_gql
#     raise SanError('Error running query: ({})'.format(e))
# san.error.SanError: Error running query: (('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer')))
# Completed 57.76% of the slugs.
# algorand
# Completed 57.87% of the slugs.
# contentos
# Completed 57.98% of the slugs.
# moviebloc
# Completed 58.1% of the slugs.
# arpa-chain
# Completed 58.21% of the slugs.
# mx-token
# Completed 58.32% of the slugs.
# ampleforth
# Completed 58.44% of the slugs.
# chiliz
# Completed 58.55% of the slugs.
# silverway
# Completed 58.66% of the slugs.
# wirex-token
# Completed 58.78% of the slugs.
# dusk-network
# Completed 58.89% of the slugs.
# coinmetro-token
# Completed 59.0% of the slugs.
# prometeus
# Completed 59.12% of the slugs.
# sapphire
# Completed 59.23% of the slugs.
# akropolis
# Completed 59.34% of the slugs.
# thorchain
# Completed 59.46% of the slugs.
# realio-network
# Completed 59.57% of the slugs.
# ultra
# Completed 59.68% of the slugs.
# ftx-token
# Completed 59.8% of the slugs.
# sharetoken
# Completed 59.91% of the slugs.
# chainx
# Completed 60.02% of the slugs.
# wink
# Completed 60.14% of the slugs.
# mb8-coin
# Completed 60.25% of the slugs.
# bosagora
# Completed 60.36% of the slugs.
# klaytn
# Completed 60.48% of the slugs.
# bitball-treasure
# Completed 60.59% of the slugs.
# swipe
# Completed 60.7% of the slugs.
# 12ships
# Completed 60.82% of the slugs.
# bitpanda-ecosystem-token
# Completed 60.93% of the slugs.
# vectorspace-ai
# Completed 61.04% of the slugs.
# nestree
# api call is still running... let's kill it...
# Completed 61.16% of the slugs.
# link
# Completed 61.27% of the slugs.
# flow
# Completed 61.38% of the slugs.
# digitalbits
# Completed 61.49% of the slugs.
# telos
# Completed 61.61% of the slugs.
# band-protocol
# Completed 61.72% of the slugs.
# binance-usd
# Completed 61.83% of the slugs.
# pax-gold
# Completed 61.95% of the slugs.
# dforce
# Completed 62.06% of the slugs.
# nucypher
# Completed 62.17% of the slugs.
# husd
# Completed 62.29% of the slugs.
# xensor
# Completed 62.4% of the slugs.
# kava
# Completed 62.51% of the slugs.
# newscrypto
# Completed 62.63% of the slugs.
# yap-stone
# Completed 62.74% of the slugs.
# multi-collateral-dai
# Completed 62.85% of the slugs.
# tellor
# Completed 62.97% of the slugs.
# nervos-network
# Completed 63.08% of the slugs.
# lcx
# Completed 63.19% of the slugs.
# zynecoin
# Completed 63.31% of the slugs.
# troy
# Completed 63.42% of the slugs.
# hex
# Completed 63.53% of the slugs.
# orchid
# Completed 63.65% of the slugs.
# mimblewimblecoin
# Completed 63.76% of the slugs.
# kusama
# Completed 63.87% of the slugs.
# veruscoin
# Completed 63.99% of the slugs.
# xenioscoin
# Completed 64.1% of the slugs.
# egoras
# Completed 64.21% of the slugs.
# apm-coin
# Completed 64.33% of the slugs.
# tachyon-protocol
# Completed 64.44% of the slugs.
# insure
# Completed 64.55% of the slugs.
# terra-krw
# Completed 64.67% of the slugs.
# origin-protocol
# Completed 64.78% of the slugs.
# orient-walt
# Completed 64.89% of the slugs.
# wazirx
# Completed 65.01% of the slugs.
# keystone-of-opportunity-knowledge
# Completed 65.12% of the slugs.
# creditcoin
# Completed 65.23% of the slugs.
# perth-mint-gold-token
# Completed 65.35% of the slugs.
# handshake
# Completed 65.46% of the slugs.
# milk-alliance
# Completed 65.57% of the slugs.
# energy-web-token
# Completed 65.69% of the slugs.
# edgeware
# Completed 65.8% of the slugs.
# bloomzed-token
# Completed 65.91% of the slugs.
# hyperdao
# Completed 66.02% of the slugs.
# orbit-chain
# Completed 66.14% of the slugs.
# proton
# Completed 66.25% of the slugs.
# peakdefi
# Completed 66.36% of the slugs.
# parsiq
# Completed 66.48% of the slugs.
# solana
# Completed 66.59% of the slugs.
# cartesi
# Completed 66.7% of the slugs.
# kardiachain
# Completed 66.82% of the slugs.
# basic
# Completed 66.93% of the slugs.
# counos-x
# Completed 67.04% of the slugs.
# just
# Completed 67.16% of the slugs.
# the-transfer-token
# Completed 67.27% of the slugs.
# tnc-coin
# Completed 67.38% of the slugs.
# hathor
# Completed 67.5% of the slugs.
# keep-network
# Completed 67.61% of the slugs.
# celo
# Completed 67.72% of the slugs.
# xdai
# Completed 67.84% of the slugs.
# secret
# Completed 67.95% of the slugs.
# somesing
# Completed 68.06% of the slugs.
# zelwin
# Completed 68.18% of the slugs.
# math
# Completed 68.29% of the slugs.
# uma
# Completed 68.4% of the slugs.
# dawn-protocol
# Completed 68.52% of the slugs.
# darma-cash
# Completed 68.63% of the slugs.
# lukso
# Completed 68.74% of the slugs.
# orion-protocol
# api call is still running... let's kill it...
# Completed 68.86% of the slugs.
# arweave
# Completed 68.97% of the slugs.
# kadena
# Completed 69.08% of the slugs.
# helium
# Completed 69.2% of the slugs.
# render-token
# Completed 69.31% of the slugs.
# skale-network
# Completed 69.42% of the slugs.
# compound
# Completed 69.54% of the slugs.
# balancer
# Completed 69.65% of the slugs.
# dmm-governance
# Completed 69.76% of the slugs.
# renbtc
# Completed 69.88% of the slugs.
# pnetwork
# Completed 69.99% of the slugs.
# darwinia-network
# Completed 70.1% of the slugs.
# sora
# Completed 70.22% of the slugs.
# defichain
# Completed 70.33% of the slugs.
# avalanche
# Completed 70.44% of the slugs.
# trustswap
# Completed 70.55% of the slugs.
# nest-protocol
# Completed 70.67% of the slugs.
# yearn-finance
# Completed 70.78% of the slugs.
# rarible
# Completed 70.89% of the slugs.
# anyswap
# Completed 71.01% of the slugs.
# casper
# Completed 71.12% of the slugs.
# nervenetwork
# Completed 71.23% of the slugs.
# dkargo
# Completed 71.35% of the slugs.
# wrapped-nxm
# Completed 71.46% of the slugs.
# tokenpocket
# Completed 71.57% of the slugs.
# yearn-finance-ii
# Completed 71.69% of the slugs.
# trust-wallet-token
# Completed 71.8% of the slugs.
# shiba-inu
# Completed 71.91% of the slugs.
# serum
# Completed 72.03% of the slugs.
# cream-finance
# Completed 72.14% of the slugs.
# unitrade
# Completed 72.25% of the slugs.
# the-sandbox
# Completed 72.37% of the slugs.
# axel
# Completed 72.48% of the slugs.
# yflink
# Completed 72.59% of the slugs.
# ecomi
# Completed 72.71% of the slugs.
# strong
# Completed 72.82% of the slugs.
# near-protocol
# Completed 72.93% of the slugs.
# mantra-dao
# Completed 73.05% of the slugs.
# degenerator-meme
# Completed 73.16% of the slugs.
# hakka-finance
# Completed 73.27% of the slugs.
# polkadot-new
# Completed 73.39% of the slugs.
# lgcy-network
# Completed 73.5% of the slugs.
# powerpool
# Completed 73.61% of the slugs.
# whale
# Completed 73.73% of the slugs.
# the-graph
# Completed 73.84% of the slugs.
# klever
# Completed 73.95% of the slugs.
# axie-infinity
# Completed 74.07% of the slugs.
# litentry
# Completed 74.18% of the slugs.
# phala-network
# Completed 74.29% of the slugs.
# radicle
# Completed 74.41% of the slugs.
# harvest-finance
# Completed 74.52% of the slugs.
# salmonswap
# Completed 74.63% of the slugs.
# elrond-egld
# Completed 74.75% of the slugs.
# hegic
# Completed 74.86% of the slugs.
# huobi-btc
# Completed 74.97% of the slugs.
# amp
# Completed 75.08% of the slugs.
# perpetual-protocol
# Completed 75.2% of the slugs.
# reef
# api call is still running... let's kill it...
# Completed 75.31% of the slugs.
# frax
# Completed 75.42% of the slugs.
# frax-share
# Completed 75.54% of the slugs.
# allianceblock
# Completed 75.65% of the slugs.
# alchemy-pay
# Completed 75.76% of the slugs.
# sun
# Completed 75.88% of the slugs.
# empty-set-dollar
# Completed 75.99% of the slugs.
# bakerytoken
# Completed 76.1% of the slugs.
# gala
# api call is still running... let's kill it...
# Completed 76.22% of the slugs.
# uniswap
# Completed 76.33% of the slugs.
# dego-finance
# Completed 76.44% of the slugs.
# bridge-oracle
# Completed 76.56% of the slugs.
# linear
# Completed 76.67% of the slugs.
# terrausd
# Completed 76.78% of the slugs.
# burger-swap
# Completed 76.9% of the slugs.
# pancakeswap
# Completed 77.01% of the slugs.
# wbnb
# Completed 77.12% of the slugs.
# titanswap
# Completed 77.24% of the slugs.
# polkastarter
# Completed 77.35% of the slugs.
# dodo
# Completed 77.46% of the slugs.
# injective-protocol
# Completed 77.58% of the slugs.
# derivadao
# api call is still running... let's kill it...
# Completed 77.69% of the slugs.
# alpha-finance-lab
# Completed 77.8% of the slugs.
# cvault-finance
# Completed 77.92% of the slugs.
# aave
# Completed 78.03% of the slugs.
# persistence
# Completed 78.14% of the slugs.
# venus
# Completed 78.26% of the slugs.
# beefy-finance
# Completed 78.37% of the slugs.
# youcash
# Completed 78.48% of the slugs.
# conflux-network
# Completed 78.6% of the slugs.
# atari-token
# Completed 78.71% of the slugs.
# akash-network
# Completed 78.82% of the slugs.
# barnbridge
# Completed 78.94% of the slugs.
# audius
# Completed 79.05% of the slugs.
# playdapp
# Completed 79.16% of the slugs.
# ramp
# Completed 79.28% of the slugs.
# rari-governance-token
# Completed 79.39% of the slugs.
# wootrade
# Completed 79.5% of the slugs.
# keep3rv1
# Completed 79.61% of the slugs.
# wemix
# Completed 79.73% of the slugs.
# dvision-network
# Completed 79.84% of the slugs.
# saffron-finance
# Completed 79.95% of the slugs.
# oasis-network
# Completed 80.07% of the slugs.
# redfox-labs
# Completed 80.18% of the slugs.
# radix
# Completed 80.29% of the slugs.
# truefi-token
# Completed 80.41% of the slugs.
# bifrost
# Completed 80.52% of the slugs.
# vai
# Completed 80.63% of the slugs.
# mirror-protocol
# Completed 80.75% of the slugs.
# badger-dao
# Completed 80.86% of the slugs.
# mobilecoin
# Completed 80.97% of the slugs.
# efforce
# Completed 81.09% of the slugs.
# bonfida
# Completed 81.2% of the slugs.
# biopassport-token
# Completed 81.31% of the slugs.
# rally
# Completed 81.43% of the slugs.
# steth
# Completed 81.54% of the slugs.
# 1inch
# Completed 81.65% of the slugs.
# safepal
# api call is still running... let's kill it...
# Completed 81.77% of the slugs.
# shopping
# Completed 81.88% of the slugs.
# nftx
# Completed 81.99% of the slugs.
# zkswap
# Completed 82.11% of the slugs.
# quickswap
# Completed 82.22% of the slugs.
# superfarm
# Completed 82.33% of the slugs.
# paid-network
# Completed 82.45% of the slugs.
# mdex
# Completed 82.56% of the slugs.
# clover
# Completed 82.67% of the slugs.
# auto
# Completed 82.79% of the slugs.
# lotto
# Completed 82.9% of the slugs.
# dao-maker
# Completed 83.01% of the slugs.
# jasmy
# Completed 83.13% of the slugs.
# hoge-finance
# Completed 83.24% of the slugs.
# everest
# Completed 83.35% of the slugs.
# apeswap-finance
# Completed 83.47% of the slugs.
# raydium
# Completed 83.58% of the slugs.
# mask-network
# Completed 83.69% of the slugs.
# alchemix
# Completed 83.81% of the slugs.
# ethernity-chain
# Completed 83.92% of the slugs.
# mina
# Completed 84.03% of the slugs.
# sovryn
# Completed 84.14% of the slugs.
# symbol
# Completed 84.26% of the slugs.
# alpaca-finance
# Completed 84.37% of the slugs.
# illuvium
# Completed 84.48% of the slugs.
# safemoon
# Completed 84.6% of the slugs.
# myneighboralice
# Completed 84.71% of the slugs.
# anchor-protocol
# Completed 84.82% of the slugs.
# strike
# Completed 84.94% of the slugs.
# internet-computer
# Completed 85.05% of the slugs.
# ellipsis
# Completed 85.16% of the slugs.
# seedify-fund
# Completed 85.28% of the slugs.
# efinity
# Completed 85.39% of the slugs.
# tokocrypto
# Completed 85.5% of the slugs.
# tribe
# Completed 85.62% of the slugs.
# pundix-new
# Completed 85.73% of the slugs.
# alien-worlds
# Completed 85.84% of the slugs.
# mobox
# Completed 85.96% of the slugs.
# cumrocket
# Completed 86.07% of the slugs.
# chia-network
# Completed 86.18% of the slugs.
# moonriver
# Completed 86.3% of the slugs.
# vulcan-forged-pyr
# Completed 86.41% of the slugs.
# ampleforth-governance-token
# Completed 86.52% of the slugs.
# dogelon
# Completed 86.64% of the slugs.
# liquity-usd
# Completed 86.75% of the slugs.
# metisdao
# Completed 86.86% of the slugs.
# wilder-world
# Completed 86.98% of the slugs.
# platon
# Completed 87.09% of the slugs.
# samoyedcoin
# Completed 87.2% of the slugs.
# apenft
# api call is still running... let's kill it...
# Completed 87.32% of the slugs.
# binaryx
# Completed 87.43% of the slugs.
# yooshi
# Completed 87.54% of the slugs.
# convex-finance
# Completed 87.66% of the slugs.
# gitcoin
# Completed 87.77% of the slugs.
# automata-network
# Completed 87.88% of the slugs.
# babyswap
# Completed 88.0% of the slugs.
# deso
# Completed 88.11% of the slugs.
# sun-token
# Completed 88.22% of the slugs.
# taboo-token
# Completed 88.34% of the slugs.
# yield-guild-games
# Completed 88.45% of the slugs.
# ufo-gaming
# Completed 88.56% of the slugs.
# derace
# Completed 88.67% of the slugs.
# biswap
# Completed 88.79% of the slugs.
# qredo
# Completed 88.9% of the slugs.
# deversifi
# Completed 89.01% of the slugs.
# metahero
# Completed 89.13% of the slugs.
# ecash
# Completed 89.24% of the slugs.
# star-link
# Completed 89.35% of the slugs.
# alitas
# Completed 89.47% of the slugs.
# coin98
# Completed 89.58% of the slugs.
# dydx
# Completed 89.69% of the slugs.
# mango-markets
# Completed 89.81% of the slugs.
# star-atlas
# Completed 89.92% of the slugs.
# star-atlas-polis
# Completed 90.03% of the slugs.
# bitdao
# Completed 90.15% of the slugs.
# wrapped-ncg
# Completed 90.26% of the slugs.
# spell-token
# Completed 90.37% of the slugs.
# superrare
# Completed 90.49% of the slugs.
# radio-caca
# Completed 90.6% of the slugs.
# joe
# Completed 90.71% of the slugs.
# toncoin
# Completed 90.83% of the slugs.
# shiden-network
# Completed 90.94% of the slugs.
# adventure-gold
# Completed 91.05% of the slugs.
# gamefi
# Completed 91.17% of the slugs.
# radix-protocol
# Completed 91.28% of the slugs.
# rmrk
# Completed 91.39% of the slugs.
# ripple
# Completed 91.51% of the slugs.
# dmd
# Completed 91.62% of the slugs.
# reddcoin
# Completed 91.73% of the slugs.
# sparkswap
# Completed 91.85% of the slugs.
# paccoin
# Completed 91.96% of the slugs.
# engine
# Completed 92.07% of the slugs.
# everrise
# Completed 92.19% of the slugs.
# library-credit
# Completed 92.3% of the slugs.
# melon
# Completed 92.41% of the slugs.
# chronotech
# Completed 92.53% of the slugs.
# mgc-token
# Completed 92.64% of the slugs.
# zencash
# Completed 92.75% of the slugs.
# cyberfi
# Completed 92.87% of the slugs.
# funfair
# Completed 92.98% of the slugs.
# dao-casino
# Completed 93.09% of the slugs.
# sun-contract
# Completed 93.2% of the slugs.
# omisego
# Completed 93.32% of the slugs.
# ethos
# Completed 93.43% of the slugs.
# binance-coin
# Completed 93.54% of the slugs.
# kickico
# Completed 93.66% of the slugs.
# connext
# Completed 93.77% of the slugs.
# modefi
# Completed 93.88% of the slugs.
# kucoin-shares
# Completed 94.0% of the slugs.
# gridplus
# Completed 94.11% of the slugs.
# streamr-datacoin
# Completed 94.22% of the slugs.
# tael
# Completed 94.34% of the slugs.
# uquid_coin
# Completed 94.45% of the slugs.
# file-coin
# Completed 94.56% of the slugs.
# dai
# Completed 94.68% of the slugs.
# internet-node-token
# Completed 94.79% of the slugs.
# theta
# Completed 94.9% of the slugs.
# smartlands
# Completed 95.02% of the slugs.
# swarm-fund
# Completed 95.13% of the slugs.
# poa-network
# api call is still running... let's kill it...
# Completed 95.24% of the slugs.
# xinfin-network
# Completed 95.36% of the slugs.
# docademic
# Completed 95.47% of the slugs.
# digitex-futures
# Completed 95.58% of the slugs.
# daps-token
# Completed 95.7% of the slugs.
# zb
# Completed 95.81% of the slugs.
# machine-xchange-coin
# Completed 95.92% of the slugs.
# rif-token
# Completed 96.04% of the slugs.
# stockchain
# Completed 96.15% of the slugs.
# futureswap
# Completed 96.26% of the slugs.
# v-id
# Completed 96.38% of the slugs.
# matic-network
# Completed 96.49% of the slugs.
# stpt
# Completed 96.6% of the slugs.
# super-zero
# Completed 96.72% of the slugs.
# forceprotocol
# Completed 96.83% of the slugs.
# luna
# Completed 96.94% of the slugs.
# noia-network
# Completed 97.06% of the slugs.
# gatechain-token
# Completed 97.17% of the slugs.
# fabric
# Completed 97.28% of the slugs.
# emirex
# Completed 97.4% of the slugs.
# acala
# Completed 97.51% of the slugs.
# hedera-hashgraph
# Completed 97.62% of the slugs.
# blockstack
# Completed 97.73% of the slugs.
# dad-chain
# Completed 97.85% of the slugs.
# neutrino-dollar
# Completed 97.96% of the slugs.
# hive
# Completed 98.07% of the slugs.
# bzx
# Completed 98.19% of the slugs.
# small-love-potion
# Completed 98.3% of the slugs.
# nexus-mutual
# Completed 98.41% of the slugs.
# dia-data
# Completed 98.53% of the slugs.
# curve
# Completed 98.64% of the slugs.
# yamv3
# Completed 98.75% of the slugs.
# crust
# Completed 98.87% of the slugs.
# sushi
# Completed 98.98% of the slugs.
# membrana
# Completed 99.09% of the slugs.
# ton-crystal
# Completed 99.21% of the slugs.
# terra-virtua-kolekt
# Completed 99.32% of the slugs.
# fei-protocol
# Completed 99.43% of the slugs.
# narrative
# Completed 99.55% of the slugs.
# bitcoin-standard-hashrate-token
# Completed 99.66% of the slugs.
# kyber-network
# Completed 99.77% of the slugs.
# BTRST
# Completed 99.89% of the slugs.
# zcoin

# %%
# Loop over the dictionary to find all the metrics in universe of slugs
san_metric_universe = []
for san_slug_key in san_slug_metrics_dict.keys():
    san_metric_universe += san_slug_metrics_dict[san_slug_key]

san_metric_universe = list(np.unique(np.array(san_metric_universe)))

# %%
# Drop anything with 5m (minute) or 1h (hour) in the name confirming the drops
metrics_1h_to_drop = [metric for metric in san_metric_universe if '1h' in metric]
for metric in metrics_1h_to_drop:
    print(metric)
    san_metric_universe.remove(metric)
    
metrics_5m_to_drop = [metric for metric in san_metric_universe if '5m' in metric]
for metric in metrics_5m_to_drop:
    print(metric)
    san_metric_universe.remove(metric)
# Out:
# active_addresses_1h
# price_usd_change_1h
# social_dominance_bitcointalk_1h_moving_average
# social_dominance_reddit_1h_moving_average
# social_dominance_telegram_1h_moving_average
# social_dominance_total_1h_moving_average
# social_dominance_total_1h_moving_average_change_1d
# social_dominance_total_1h_moving_average_change_30d
# social_dominance_total_1h_moving_average_change_7d
# social_dominance_twitter_1h_moving_average
# unique_social_volume_total_1h
# active_deposits_5m
# active_withdrawals_5m
# average_fees_usd_5m
# average_transfer_5m
# deposit_transactions_5m
# median_fees_usd_5m
# median_transfer_5m
# nvt_5min
# price_usd_5m
# unique_social_volume_total_5m
# withdrawal_transactions_5m

# %%
# Go thru the metrics to drop ones that I manually just don't want
metrics_to_drop = ["30d_moving_avg_dev_activity_change_1d",
                   "active_addresses_24h_change_1d",
                   "active_addresses_24h_change_30d",
                   "active_addresses_24h_change_7d",
                   "bitmex_perpetual_funding_rate_change_1d",
                   "bitmex_perpetual_funding_rate_change_30d",
                   "bitmex_perpetual_funding_rate_change_7d",
                   "cexes_to_defi_flow_change_1d",
                   "cexes_to_defi_flow_change_30d",
                   "cexes_to_defi_flow_change_7d",
                   "cexes_to_dex_flow_change_30d",
                   "cexes_to_dex_traders_flow_change_1d",
                   "cexes_to_dex_traders_flow_change_30d",
                   "cexes_to_dex_traders_flow_change_7d",
                   "cexes_to_other_flow_change_1d",
                   "cexes_to_other_flow_change_30d",
                   "cexes_to_other_flow_change_7d",
                   "cexes_to_whale_flow_change_1d",
                   "cexes_to_whale_flow_change_30d",
                   "cexes_to_whale_flow_change_7d",
                   "circulation_180d_change_1d",
                   "circulation_180d_change_30d",
                   "circulation_180d_change_7d",
                   "circulation_change_1d",
                   "circulation_change_30d",
                   "circulation_change_7d",
                   "circulation_usd_180d_change_1d",
                   "circulation_usd_180d_change_30d",
                   "circulation_usd_180d_change_7d",
                   "daily_closing_marketcap_usd",
                   "daily_closing_price_usd",
                   "daily_high_price_usd",
                   "daily_low_price_usd",
                   "daily_opening_price_usd",
                   "defi_to_cexes_flow_change_1d",
                   "defi_to_cexes_flow_change_30d",
                   "defi_to_cexes_flow_change_7d",
                   "defi_to_dex_traders_flow_change_1d",
                   "defi_to_dex_traders_flow_change_30d",
                   "defi_to_dex_traders_flow_change_7d",
                   "defi_to_dexes_flow_change_1d",
                   "defi_to_dexes_flow_change_30d",
                   "defi_to_dexes_flow_change_7d",
                   "defi_to_other_flow_change_1d",
                   "defi_to_other_flow_change_30d",
                   "defi_to_other_flow_change_7d",
                   "defi_to_whale_flow_change_1d",
                   "defi_to_whale_flow_change_30d",
                   "defi_to_whale_flow_change_7d",
                   "dev_activity_change_1d",
                   "dev_activity_change_30d",
                   "dev_activity_change_7d",
                   'dex_to_cexes_flow_change_30d',
                   'dex_to_cexes_flow_change_7d',
                   "dex_traders_to_cexes_flow_change_1d",
                   "dex_traders_to_cexes_flow_change_30d",
                   "dex_traders_to_cexes_flow_change_7d",
                   "dex_traders_to_defi_flow_change_1d",
                   "dex_traders_to_defi_flow_change_30d",
                   "dex_traders_to_defi_flow_change_7d",
                   "dex_traders_to_dexes_flow_change_1d",
                   "dex_traders_to_dexes_flow_change_30d",
                   "dex_traders_to_dexes_flow_change_7d",
                   "dex_traders_to_other_flow_change_1d",
                   "dex_traders_to_other_flow_change_30d",
                   "dex_traders_to_other_flow_change_7d",
                   "dex_traders_to_whale_flow_change_1d",
                   "dex_traders_to_whale_flow_change_30d",
                   "dex_traders_to_whale_flow_change_7d",
                   "dexes_to_defi_flow_change_1d",
                   "dexes_to_defi_flow_change_30d",
                   "dexes_to_defi_flow_change_7d",
                   "dexes_to_dex_traders_flow_change_1d",
                   "dexes_to_dex_traders_flow_change_30d",
                   "dexes_to_dex_traders_flow_change_7d",
                   "dexes_to_other_flow_change_1d",
                   "dexes_to_other_flow_change_30d",
                   "dexes_to_other_flow_change_7d",
                   "dexes_to_whale_flow_change_1d",
                   "dexes_to_whale_flow_change_30d",
                   "dexes_to_whale_flow_change_7d",
                   "dormant_circulation_365d_change_1d",
                   "dormant_circulation_365d_change_30d",
                   "dormant_circulation_365d_change_7d",
                   "dormant_circulation_usd_180d_change_1d",
                   "dormant_circulation_usd_180d_change_30d",
                   "dormant_circulation_usd_180d_change_7d",
                   "exchange_balance_change_1d",
                   "exchange_balance_change_30d",
                   "exchange_balance_change_7d",
                   "exchange_inflow_change_1d",
                   "exchange_inflow_change_30d",
                   "exchange_inflow_change_7d",
                   "exchange_inflow_usd_change_1d",
                   "exchange_inflow_usd_change_30d",
                   "exchange_inflow_usd_change_7d",
                   "exchange_outflow_change_1d",
                   "exchange_outflow_change_30d",
                   "exchange_outflow_change_7d",
                   "exchange_outflow_usd_change_1d",
                   "exchange_outflow_usd_change_30d",
                   "exchange_outflow_usd_change_7d",
                   'historical_balance',
                   'historical_balance_changes',
                   "marketcap_usd_change_1d",
                   "marketcap_usd_change_30d",
                   "marketcap_usd_change_7d",
                   "mean_dollar_invested_age_change_1d",
                   "mean_dollar_invested_age_change_30d",
                   "mean_dollar_invested_age_change_7d",
                   "mvrv_usd_180d_change_1d",
                   "mvrv_usd_180d_change_30d",
                   "mvrv_usd_180d_change_7d",
                   "mvrv_usd_30d_change_1d",
                   "mvrv_usd_30d_change_30d",
                   "mvrv_usd_30d_change_7d",
                   "mvrv_usd_365d_change_1d",
                   "mvrv_usd_365d_change_30d",
                   "mvrv_usd_365d_change_7d",
                   "mvrv_usd_change_1d",
                   "mvrv_usd_change_30d",
                   "mvrv_usd_change_7d",
                   "network_profit_loss_change_1d",
                   "network_profit_loss_change_30d",
                   "network_profit_loss_change_7d",
                   "other_to_cexes_flow_change_1d",
                   "other_to_cexes_flow_change_30d",
                   "other_to_cexes_flow_change_7d",
                   "other_to_defi_flow_change_1d",
                   "other_to_defi_flow_change_30d",
                   "other_to_defi_flow_change_7d",
                   "other_to_dexes_flow_change_1d",
                   "other_to_dexes_flow_change_30d",
                   "other_to_dexes_flow_change_7d",
                   "other_to_traders_flow_change_1d",
                   "other_to_traders_flow_change_30d",
                   "other_to_traders_flow_change_7d",
                   "other_to_whale_flow_change_1d",
                   "other_to_whale_flow_change_30d",
                   "other_to_whale_flow_change_7d",
                   "price_btc_change_1d",
                   "price_btc_change_30d",
                   "price_btc_change_7d",
                   "price_eth_change_1d",
                   "price_eth_change_30d",
                   "price_eth_change_7d",
                   "price_usd_change_1d",
                   "price_usd_change_30d",
                   "price_usd_change_7d",
                   "sentiment_balance_total_change_1d",
                   "sentiment_balance_total_change_30d",
                   "sentiment_balance_total_change_7d",
                   "sentiment_volume_consumed_total_change_1d",
                   "sentiment_volume_consumed_total_change_30d",
                   "sentiment_volume_consumed_total_change_7d",
                   'social_active_users',
                   "social_dominance_bitcointalk_24h_moving_average",
                   "social_dominance_reddit_24h_moving_average",
                   "social_dominance_telegram_24h_moving_average",
                   "social_dominance_total_24h_moving_average",
                   "social_dominance_total_24h_moving_average_change_1d",
                   "social_dominance_total_24h_moving_average_change_30d",
                   "social_dominance_total_24h_moving_average_change_7d",
                   "social_dominance_total_change_1d",
                   "social_dominance_total_change_30d",
                   "social_dominance_total_change_7d",
                   "social_dominance_twitter_24h_moving_average",
                   "social_volume_total_change_1d",
                   "social_volume_total_change_30d",
                   "social_volume_total_change_7d",
                   "traders_to_other_flow_change_1d",
                   "traders_to_other_flow_change_30d",
                   "traders_to_other_flow_change_7d",
                   "traders_to_whale_flow_change_1d",
                   "traders_to_whale_flow_change_30d",
                   "traders_to_whale_flow_change_7d",
                   "transaction_volume_change_1d",
                   "transaction_volume_change_30d",
                   "transaction_volume_change_7d",
                   "transaction_volume_usd_change_1d",
                   "transaction_volume_usd_change_30d",
                   "transaction_volume_usd_change_7d",
                   "volume_usd_change_1d",
                   "volume_usd_change_30d",
                   "volume_usd_change_7d",
                   "whale_to_cexes_flow_change_1d",
                   "whale_to_cexes_flow_change_30d",
                   "whale_to_cexes_flow_change_7d",
                   "whale_to_defi_flow_change_1d",
                   "whale_to_defi_flow_change_30d",
                   "whale_to_defi_flow_change_7d",
                   "whale_to_dex_traders_flow_change_1d",
                   "whale_to_dex_traders_flow_change_30d",
                   "whale_to_dex_traders_flow_change_7d",
                   "whale_to_dexes_flow_change_1d",
                   "whale_to_dexes_flow_change_30d",
                   "whale_to_dexes_flow_change_7d",
                   "whale_to_other_flow_change_1d",
                   "whale_to_other_flow_change_30d",
                   "whale_to_other_flow_change_7d",
                   "whale_to_traders_flow_change_1d",
                   "whale_to_traders_flow_change_30d",
                   "whale_to_traders_flow_change_7d",
                   "whale_transaction_count_100k_usd_to_inf_change_1d",
                   "whale_transaction_count_100k_usd_to_inf_change_30d",
                   "whale_transaction_count_100k_usd_to_inf_change_7d",
                   "whale_transaction_count_1m_usd_to_inf_change_1d",
                   "whale_transaction_count_1m_usd_to_inf_change_30d",
                   "whale_transaction_count_1m_usd_to_inf_change_7d",
                   'withdrawal_balance']

for metric in metrics_to_drop: 
    san_metric_universe.remove(metric)

# %%
# Create a data frame of how many assets are available for each metric
assets_per_metric_dict = {'metric': [],
                          'num_assets': []}

for metric in san_metric_universe:
    # Initialize counter to zero
    num_assets = 0
    
    # Loop over all the assets to see if each has the metric to increment if so
    for asset in san_slug_metrics_dict:
        if metric in san_slug_metrics_dict[asset]:
            num_assets += 1
  
    # Update result dictionary with number of assets that have the metric
    assets_per_metric_dict['metric'].append(metric)
    assets_per_metric_dict['num_assets'].append(num_assets)
    
# Clean up into a df
assets_per_metric_df = pd.DataFrame(assets_per_metric_dict)
assets_per_metric_df = assets_per_metric_df.sort_values(by='num_assets', ascending=False).reset_index(drop=True)

# %%
# Drop the lower metrics
index_to_keep_to = 366
assert assets_per_metric_df.metric.values[index_to_keep_to] == 'stock_to_flow'
timeseries_metrics = list(assets_per_metric_df[:(index_to_keep_to+1)].metric.values)
timeseries_metrics.remove('age_distribution')
histogram_metrics = ['age_distribution']

# %%
def obtainSlugsForMetric(metric):
    san_slugs_for_metric_dict['san_slugs'] = san.metadata(metric, arr=['availableSlugs'])['availableSlugs']
    time.sleep(1.21)

def obtainStartTimeforMetric(metric, san_slug):
    time_start_dict[san_slug] = san.available_metric_for_slug_since(metric=metric, slug=san_slug)
    time.sleep(1.21)

# Drop metrics that are not available early enough
valid_timeseries_metrics     = []
failed_pulls_list            = []
failed_pulls_time_start_list = []
i=0
num_metrics = len(timeseries_metrics)
for metric in timeseries_metrics[i:]:
    print(metric)
    print('Completed ' + str(np.round(i/num_metrics * 100, 2)) + '% of the metrics.')
    i += 1
    
    # Obtain a slug that is available for the metric
    manager = multiprocessing.Manager()
    san_slugs_for_metric_dict = manager.dict()
    p = multiprocessing.Process(target=obtainSlugsForMetric, args=(metric, ))
    p.start()
    
    # if thread is active
    time.sleep(2)
    if p.is_alive():
        print("api call is still running... let's kill it...")
        p.terminate()
        p = multiprocessing.Process(target=obtainSlugsForMetric, args=(metric, ))
        p.start()
        time.sleep(3)
        if p.is_alive():
            print('api call failed twice\n')
            p.terminate()
            failed_pulls_list.append(metric)
            continue
    
    p.join()
    san_slugs_for_metric = san_slugs_for_metric_dict['san_slugs']
    if 'bitcoin' in san_slugs_for_metric:
        san_slug = 'bitcoin'
    elif 'ethereum' in san_slugs_for_metric:
        san_slug = 'ethereum'
    elif 'cardano' in san_slugs_for_metric:
        san_slug = 'cardano'
    elif 'decentraland' in san_slugs_for_metric:
        san_slug = 'decentraland'
    else:
        print(san_slugs_for_metric)
        assert(1==0)
        
    # Obtain the time the metric starts
    manager = multiprocessing.Manager()
    time_start_dict = manager.dict()
    p = multiprocessing.Process(target=obtainStartTimeforMetric, args=(metric, san_slug))
    p.start()
    
    # if thread is active
    time.sleep(2)
    if p.is_alive():
        print("api call is still running... let's kill it...")
        p.terminate()
        p = multiprocessing.Process(target=obtainStartTimeforMetric, args=(metric, san_slug))
        p.start()
        time.sleep(3)
        if p.is_alive():
            print('api call failed twice\n')
            p.terminate()
            failed_pulls_time_start_list.append(metric)
            continue
    
    p.join()
    time_start = dt.datetime.strptime(time_start_dict[san_slug], '%Y-%m-%dT%H:%M:%SZ')
    
    if time_start.year >= 2018:
        print('We are losing ' + metric + ' given it starts in ' + str(time_start.year) + '.')
    elif time_start.year <= 2017:
        valid_timeseries_metrics.append(metric)
    else:
        assert (1==0),('PROBLEM!')
        
    time.sleep(2)
    print('\n')
        
print(failed_pulls_list)
print(failed_pulls_time_start_list)
# Out:
# ftx_perpetual_funding_rate
# Completed 95.9% of the metrics.
# We are losing ftx_perpetual_funding_rate given it starts in 2019.
#
#
# ftx_perpetual_open_interest
# Completed 96.17% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing ftx_perpetual_open_interest given it starts in 2022.
#
#
# traders_defi_balance
# Completed 96.45% of the metrics.
# api call is still running... let's kill it...
#
#
# usdt_binance_funding_rate
# Completed 96.72% of the metrics.
# api call is still running... let's kill it...
# We are losing usdt_binance_funding_rate given it starts in 2019.
#
#
# usdt_bnb_funding_rates
# Completed 96.99% of the metrics.
# api call is still running... let's kill it...
# We are losing usdt_bnb_funding_rates given it starts in 2019.
#
#
# usdt_binance_open_value
# Completed 97.27% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing usdt_binance_open_value given it starts in 2022.
#
#
# usdt_bnb_open_interest
# Completed 97.54% of the metrics.
# api call is still running... let's kill it...
# We are losing usdt_bnb_open_interest given it starts in 2022.
#
#
# usdt_bnb_open_value
# Completed 97.81% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing usdt_bnb_open_value given it starts in 2022.
#
#
# usdt_binance_open_interest
# Completed 98.09% of the metrics.
# api call is still running... let's kill it...
# We are losing usdt_binance_open_interest given it starts in 2022.
#
#
# dex_traders_defi_balance
# Completed 98.36% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
#
#
# defi_to_traders_flow
# Completed 98.63% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
#
#
# huobi_perpetual_funding_rate
# Completed 98.91% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing huobi_perpetual_funding_rate given it starts in 2020.
#
#
# traders_to_defi_flow
# Completed 99.18% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
#
#
# defi_to_dex_traders_flow
# Completed 99.45% of the metrics.
# api call is still running... let's kill it...
#
#
# stock_to_flow
# Completed 99.73% of the metrics.
# api call is still running... let's kill it...
#
#
# ['sentiment_positive_bitcointalk', 'realized_value_usd_1d', 'holders_labeled_negative_distribution_combined_balance_10_to_100', 'amount_in_top_holders', 'total_supply_in_profit', 'dex_traders_to_other_flow']
# ['holders_distribution_combined_balance_over_100k', 'holders_distribution_100k_to_1M']

# %%
# Clean it up
valid_timeseries_metrics = list(np.unique(np.array(valid_timeseries_metrics)))

# %%
# Function to obtain timeseries data
def obtainTimeseriesData(metric, san_slug):
    temp_df = san.get(metric + '/' + san_slug,
                      from_date="2015-01-01",
                      to_date="2022-01-07",
                      interval="1d")
    time.sleep(.121)
    if not temp_df.empty:
        temp_df['san_slug'] = san_slug
        metric_dict['date'] = temp_df.index.values
        metric_dict['san_slug'] = temp_df['san_slug'].values
        metric_dict[metric] = temp_df['value'].values

# Initialize dataframe to store all results
ts_df = pd.DataFrame(data={'date': [],
                           'san_slug': []})

# Initialize dictionary to keep track of the data we missed
failed_pulls_dict = {}

# Loop over all the metrics to pull the data
i = 0
num_metrics = len(valid_timeseries_metrics)
for metric in valid_timeseries_metrics[i:]:
    print(metric)
    print('Completed ' + str(np.round(i/num_metrics * 100, 2)) + '% of the metrics.\n')
    i += 1

    # Initialize dataframe to store results for this metric
    metric_df = pd.DataFrame()
    failed_pulls_dict[metric] = []

    # Obtain the list of slugs that have this metric
    san_slugs = []
    for san_slug in san_slug_metrics_dict:
        if metric in san_slug_metrics_dict[san_slug]:
            san_slugs.append(san_slug)

    # Drop san slugs that are not in our universe
    san_slugs = list(set(san_slugs).intersection(set(san_slugs_list)))

    # Loop over all the slugs to pull the data
    j = 0
    num_slugs = len(san_slugs)
    for san_slug in san_slugs:
        print('Completed ' + str(np.round(j/num_slugs * 100, 2)) + '% of the slugs for this metric.')
        j += 1

        # Initiate the call as a process
        manager = multiprocessing.Manager()
        metric_dict = manager.dict()
        p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
        p.start()

        time.sleep(3)
        # If thread is active
        if p.is_alive():
            print("api call is still running... let's kill it...")
            p.terminate()

            # Try the call again
            manager = multiprocessing.Manager()
            metric_dict = manager.dict()
            p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
            p.start()
            time.sleep(4)
            if p.is_alive():
                print('api call failed twice')
                p.terminate()

                # Try the call one last time
                manager = multiprocessing.Manager()
                metric_dict = manager.dict()
                p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
                p.start()
                time.sleep(5)
                if p.is_alive():
                    print('api call failed thrice\n')
                    p.terminate()
                    failed_pulls_dict[metric].append(san_slug)
                    continue

        # Cleanup
        p.join()

        # Add results for this slug and metric to metric dataframe
        # only if the pull was successful
        if len(metric_dict.keys()) >= 1:
            metric_df = metric_df.append(pd.DataFrame(data={'date': metric_dict['date'],
                                                            'san_slug': metric_dict['san_slug'],
                                                            metric: metric_dict[metric]}))
            assert(0==metric_df[metric_df.duplicated(subset=['date', 'san_slug'])].shape[0]),('duped rows')
        else:
            failed_pulls_dict[metric].append(san_slug)
            print('For '+san_slug+' pull of '+metric+', we received no data so it is skipped.\n')
            
    # Merge each metrics dataframe onto the master df
    ts_df = ts_df.merge(metric_df,
                        on=['date', 'san_slug'],
                        how='outer',
                        validate='one_to_one')

    # Space out prints
    print('\n\n\n')

# %%
# Clean up ts_df 
ts_df = ts_df[~ts_df.duplicated(subset=['date', 'san_slug'])]
ts_df = ts_df.sort_values(by = ['date', 'san_slug'])

# %%
# Build dictionary of macro metrics and corresponding slugs to pull data for

macro_metric_slugs_dict = {}
macro_metric_slugs_dict['mcd_collat_ratio'] = ["wrapped-bitcoin", "gemini-dollar",
                                               "usd-coin", "paxos-standard",
                                               "decentraland", "trueusd",
                                               "yearn-finance", "chainlink",
                                               "weth", "balancer"]
macro_metric_slugs_dict['defi_total_value_locked_usd'] = ['ethereum']
macro_metric_slugs_dict['nft_trade_volume_usd'] = ['ethereum']
macro_metric_slugs_dict['nft_trades_count'] = ['ethereum']
macro_metric_slugs_dict['nft_retail_trade_volume_usd'] = ['ethereum']
macro_metric_slugs_dict['nft_whale_trade_volume_usd'] = ['ethereum']
macro_metric_slugs_dict['nft_whale_trades_count'] = ['ethereum']
macro_metric_slugs_dict['percent_of_whale_stablecoin_total_supply'] = ['ethereum']
macro_metric_slugs_dict['average_fees_usd'] = ['ethereum']
macro_metric_slugs_dict['fees_usd'] = ['ethereum']
macro_metric_slugs_dict['eth2_roi'] = ['ethereum']
macro_metric_slugs_dict['median_fees_usd'] = ['ethereum']
macro_metric_slugs_dict['miners_to_exchanges_flow'] = ['ethereum', 'bitcoin']
macro_metric_slugs_dict['miners_exchange_balance'] = ['ethereum', 'bitcoin']

# Determine slugs that are available for the following macro metrics
macro_metrics = ['defi_to_dexes_flow',
                 'defi_dex_balance',
                 'cexes_to_dex_flow',
                 'dexes_to_defi_flow',
                 'defi_to_cexes_flow',
                 'defi_to_exchanges_flow',
                 'exchanges_to_defi_flow',
                 'whale_to_defi_flow', 
                 'dex_traders_to_defi_flow',
                 'whale_defi_balance',
                 'mvrv_usd_intraday']

def obtainSlugsForMetric(metric):
    san_slugs_for_metric_dict['san_slugs'] = san.metadata(metric, arr=['availableSlugs'])['availableSlugs']
    time.sleep(1.21)

def obtainStartTimeforMetric(metric, san_slug):
    time_start_dict[san_slug] = san.available_metric_for_slug_since(metric=metric, slug=san_slug)
    time.sleep(1.21)

# Drop metrics that are not available early enough
failed_pulls_list_macro            = []
failed_pulls_time_start_list_macro = []
i=0
num_metrics = len(macro_metrics)
for metric in macro_metrics[i:]:
    print(metric)
    print('Completed ' + str(np.round(i/num_metrics * 100, 2)) + '% of the metrics.')
    i += 1
    
    # Obtain a slug that is available for the metric
    manager = multiprocessing.Manager()
    san_slugs_for_metric_dict = manager.dict()
    p = multiprocessing.Process(target=obtainSlugsForMetric, args=(metric, ))
    p.start()
    
    # if thread is active
    time.sleep(2)
    if p.is_alive():
        print("api call is still running... let's kill it...")
        p.terminate()
        p = multiprocessing.Process(target=obtainSlugsForMetric, args=(metric, ))
        p.start()
        time.sleep(3)
        if p.is_alive():
            print('api call failed twice\n')
            p.terminate()
            failed_pulls_list.append(metric)
            continue
    
    p.join()
    san_slugs_for_metric = san_slugs_for_metric_dict['san_slugs']
    if 'bitcoin' in san_slugs_for_metric:
        san_slug = 'bitcoin'
    elif 'ethereum' in san_slugs_for_metric:
        san_slug = 'ethereum'
    elif 'cardano' in san_slugs_for_metric:
        san_slug = 'cardano'
    elif 'tether' in san_slugs_for_metric:
        san_slug = 'decentraland'
    else:
        print(san_slugs_for_metric)
        assert(1==0)
        
    # Obtain the time the metric starts
    manager = multiprocessing.Manager()
    time_start_dict = manager.dict()
    p = multiprocessing.Process(target=obtainStartTimeforMetric, args=(metric, san_slug))
    p.start()
    
    # if thread is active
    time.sleep(2)
    if p.is_alive():
        print("api call is still running... let's kill it...")
        p.terminate()
        p = multiprocessing.Process(target=obtainStartTimeforMetric, args=(metric, san_slug))
        p.start()
        time.sleep(3)
        if p.is_alive():
            print('api call failed twice\n')
            p.terminate()
            failed_pulls_time_start_list.append(metric)
            continue
    
    p.join()
    time_start = dt.datetime.strptime(time_start_dict[san_slug], '%Y-%m-%dT%H:%M:%SZ')
    
    if time_start.year >= 2018:
        print('We are losing ' + metric + ' given it starts in ' + str(time_start.year) + '.')
    elif time_start.year <= 2017:
        macro_metric_slugs_dict[metric] = san_slugs_for_metric
    else:
        assert (1==0),('PROBLEM!')
        
    time.sleep(2)
    print('\n')
        
print(failed_pulls_list_macro)
print(failed_pulls_time_start_list_macro)
# Out:
# defi_to_dexes_flow
# Completed 0.0% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing defi_to_dexes_flow given it starts in 2018.
#
#
# defi_dex_balance
# Completed 9.09% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing defi_dex_balance given it starts in 2018.
#
#
# cexes_to_dex_flow
# Completed 18.18% of the metrics.
#
#
# dexes_to_defi_flow
# Completed 27.27% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing dexes_to_defi_flow given it starts in 2018.
#
#
# defi_to_cexes_flow
# Completed 36.36% of the metrics.
# api call is still running... let's kill it...
# We are losing defi_to_cexes_flow given it starts in 2018.
#
#
# defi_to_exchanges_flow
# Completed 45.45% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
# We are losing defi_to_exchanges_flow given it starts in 2018.
#
#
# exchanges_to_defi_flow
# Completed 54.55% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
#
#
# whale_to_defi_flow
# Completed 63.64% of the metrics.
# api call is still running... let's kill it...
#
#
# dex_traders_to_defi_flow
# Completed 72.73% of the metrics.
# api call is still running... let's kill it...
#
#
# whale_defi_balance
# Completed 81.82% of the metrics.
# api call is still running... let's kill it...
#
#
# mvrv_usd_intraday
# Completed 90.91% of the metrics.
# api call is still running... let's kill it...
# api call is still running... let's kill it...
#
#
# []
# []

# %%
# Obtain the macro timeseries data
def obtainTimeseriesData(metric, san_slug):
    temp_df = san.get(metric + '/' + san_slug,
                      from_date="2015-01-01",
                      to_date="2022-01-07",
                      interval="1d")
    time.sleep(.121)
    if not temp_df.empty:
        temp_df['san_slug'] = san_slug
        metric_dict['date'] = temp_df.index.values
        metric_dict['san_slug'] = temp_df['san_slug'].values
        metric_dict[metric] = temp_df['value'].values

# Initialize dataframe to store all results
macro_df = pd.DataFrame(data={'date': [],
                              'san_slug': []})

# Initialize dictionary to keep track of the data we missed
failed_pulls_dict = {}

# Loop over all the metrics to pull the data
i = 0
num_metrics = len(list(macro_metric_slugs_dict.keys()))
for metric in list(macro_metric_slugs_dict.keys())[i:]:
    print(metric)
    print('Completed ' + str(np.round(i/num_metrics * 100, 2)) + '% of the metrics.\n')
    i += 1

    # Initialize dataframe to store results for this metric
    metric_df = pd.DataFrame()
    failed_pulls_dict[metric] = []

    # Obtain the list of slugs that have this metric
    san_slugs = macro_metric_slugs_dict[metric]
    
    # Drop wrapped-bitcoin
    if ('bitcoin' in san_slugs) and ('wrapped-bitcoin' in san_slugs):
        san_slugs.remove('wrapped-bitcoin')
        
    # Loop over all the slugs to pull the data
    j = 0
    num_slugs = len(san_slugs)
    for san_slug in san_slugs:
        print('Completed ' + str(np.round(j/num_slugs * 100, 2)) + '% of the slugs for this metric.')
        j += 1

        # Initiate the call as a process
        manager = multiprocessing.Manager()
        metric_dict = manager.dict()
        p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
        p.start()

        time.sleep(3)
        # If thread is active
        if p.is_alive():
            print("api call is still running... let's kill it...")
            p.terminate()

            # Try the call again
            manager = multiprocessing.Manager()
            metric_dict = manager.dict()
            p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
            p.start()
            time.sleep(4)
            if p.is_alive():
                print('api call failed twice')
                p.terminate()

                # Try the call one last time
                manager = multiprocessing.Manager()
                metric_dict = manager.dict()
                p = multiprocessing.Process(target=obtainTimeseriesData, args=(metric, san_slug))
                p.start()
                time.sleep(5)
                if p.is_alive():
                    print('api call failed thrice\n')
                    p.terminate()
                    failed_pulls_dict[metric].append(san_slug)
                    continue

        # Cleanup
        p.join()

        # Add results for this slug and metric to metric dataframe
        # only if the pull was successful
        if len(metric_dict.keys()) >= 1:
            metric_df = metric_df.append(pd.DataFrame(data={'date': metric_dict['date'],
                                                            'san_slug': metric_dict['san_slug'],
                                                            metric: metric_dict[metric]}))
            assert(0==metric_df[metric_df.duplicated(subset=['date', 'san_slug'])].shape[0]),('duped rows')
        else:
            failed_pulls_dict[metric].append(san_slug)
            print('For '+san_slug+' pull of '+metric+', we received no data so it is skipped.\n')
            
    # Merge each metrics dataframe onto the master df
    macro_df = macro_df.merge(metric_df,
                              on=['date', 'san_slug'],
                              how='outer',
                              validate='one_to_one')

    # Space out prints
    print('\n\n\n')
# Out:
# mcd_collat_ratio
# Completed 0.0% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 10.0% of the slugs for this metric.
# Completed 20.0% of the slugs for this metric.
# Completed 30.0% of the slugs for this metric.
# Completed 40.0% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
# Completed 60.0% of the slugs for this metric.
# Completed 70.0% of the slugs for this metric.
# Completed 80.0% of the slugs for this metric.
# Completed 90.0% of the slugs for this metric.
#
#
#
#
# scd_collat_ratio
# Completed 4.76% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# defi_total_value_locked_usd
# Completed 9.52% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# nft_trade_volume_usd
# Completed 14.29% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# nft_trades_count
# Completed 19.05% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# nft_retail_trade_volume_usd
# Completed 23.81% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# nft_whale_trade_volume_usd
# Completed 28.57% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# nft_whale_trades_count
# Completed 33.33% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# percent_of_whale_stablecoin_total_supply
# Completed 38.1% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# average_fees_usd
# Completed 42.86% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# fees_usd
# Completed 47.62% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# eth2_roi
# Completed 52.38% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
#
#
#
#
# median_fees_usd
# Completed 57.14% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# api call is still running... let's kill it...
#
#
#
#
# miners_to_exchanges_flow
# Completed 61.9% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
#
#
#
#
# miners_exchange_balance
# Completed 66.67% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
# For bitcoin pull of miners_exchange_balance, we received no data so it is skipped.
#
#
#
#
#
# cexes_to_dex_flow
# Completed 71.43% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 9.09% of the slugs for this metric.
# Completed 18.18% of the slugs for this metric.
# Completed 27.27% of the slugs for this metric.
# Completed 36.36% of the slugs for this metric.
# Completed 45.45% of the slugs for this metric.
# Completed 54.55% of the slugs for this metric.
# Completed 63.64% of the slugs for this metric.
# Completed 72.73% of the slugs for this metric.
# Completed 81.82% of the slugs for this metric.
# Completed 90.91% of the slugs for this metric.
#
#
#
#
# exchanges_to_defi_flow
# Completed 76.19% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 10.0% of the slugs for this metric.
# Completed 20.0% of the slugs for this metric.
# Completed 30.0% of the slugs for this metric.
# Completed 40.0% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
# Completed 60.0% of the slugs for this metric.
# Completed 70.0% of the slugs for this metric.
# Completed 80.0% of the slugs for this metric.
# Completed 90.0% of the slugs for this metric.
#
#
#
#
# whale_to_defi_flow
# Completed 80.95% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 0.93% of the slugs for this metric.
# Completed 1.85% of the slugs for this metric.
# Completed 2.78% of the slugs for this metric.
# Completed 3.7% of the slugs for this metric.
# Completed 4.63% of the slugs for this metric.
# Completed 5.56% of the slugs for this metric.
# Completed 6.48% of the slugs for this metric.
# Completed 7.41% of the slugs for this metric.
# Completed 8.33% of the slugs for this metric.
# Completed 9.26% of the slugs for this metric.
# Completed 10.19% of the slugs for this metric.
# Completed 11.11% of the slugs for this metric.
# Completed 12.04% of the slugs for this metric.
# Completed 12.96% of the slugs for this metric.
# Completed 13.89% of the slugs for this metric.
# Completed 14.81% of the slugs for this metric.
# Completed 15.74% of the slugs for this metric.
# Completed 16.67% of the slugs for this metric.
# Completed 17.59% of the slugs for this metric.
# Completed 18.52% of the slugs for this metric.
# Completed 19.44% of the slugs for this metric.
# Completed 20.37% of the slugs for this metric.
# Completed 21.3% of the slugs for this metric.
# Completed 22.22% of the slugs for this metric.
# Completed 23.15% of the slugs for this metric.
# Completed 24.07% of the slugs for this metric.
# Completed 25.0% of the slugs for this metric.
# Completed 25.93% of the slugs for this metric.
# Completed 26.85% of the slugs for this metric.
# Completed 27.78% of the slugs for this metric.
# Completed 28.7% of the slugs for this metric.
# Completed 29.63% of the slugs for this metric.
# Completed 30.56% of the slugs for this metric.
# Completed 31.48% of the slugs for this metric.
# Completed 32.41% of the slugs for this metric.
# Completed 33.33% of the slugs for this metric.
# Completed 34.26% of the slugs for this metric.
# Completed 35.19% of the slugs for this metric.
# Completed 36.11% of the slugs for this metric.
# Completed 37.04% of the slugs for this metric.
# Completed 37.96% of the slugs for this metric.
# Completed 38.89% of the slugs for this metric.
# Completed 39.81% of the slugs for this metric.
# Completed 40.74% of the slugs for this metric.
# Completed 41.67% of the slugs for this metric.
# Completed 42.59% of the slugs for this metric.
# Completed 43.52% of the slugs for this metric.
# Completed 44.44% of the slugs for this metric.
# Completed 45.37% of the slugs for this metric.
# Completed 46.3% of the slugs for this metric.
# Completed 47.22% of the slugs for this metric.
# Completed 48.15% of the slugs for this metric.
# Completed 49.07% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
# Completed 50.93% of the slugs for this metric.
# Completed 51.85% of the slugs for this metric.
# Completed 52.78% of the slugs for this metric.
# Completed 53.7% of the slugs for this metric.
# Completed 54.63% of the slugs for this metric.
# Completed 55.56% of the slugs for this metric.
# Completed 56.48% of the slugs for this metric.
# Completed 57.41% of the slugs for this metric.
# Completed 58.33% of the slugs for this metric.
# Completed 59.26% of the slugs for this metric.
# Completed 60.19% of the slugs for this metric.
# Completed 61.11% of the slugs for this metric.
# Completed 62.04% of the slugs for this metric.
# Completed 62.96% of the slugs for this metric.
# Completed 63.89% of the slugs for this metric.
# Completed 64.81% of the slugs for this metric.
# Completed 65.74% of the slugs for this metric.
# Completed 66.67% of the slugs for this metric.
# Completed 67.59% of the slugs for this metric.
# Completed 68.52% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 69.44% of the slugs for this metric.
# Completed 70.37% of the slugs for this metric.
# Completed 71.3% of the slugs for this metric.
# Completed 72.22% of the slugs for this metric.
# Completed 73.15% of the slugs for this metric.
# Completed 74.07% of the slugs for this metric.
# Completed 75.0% of the slugs for this metric.
# Completed 75.93% of the slugs for this metric.
# Completed 76.85% of the slugs for this metric.
# Completed 77.78% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 78.7% of the slugs for this metric.
# Completed 79.63% of the slugs for this metric.
# Completed 80.56% of the slugs for this metric.
# Completed 81.48% of the slugs for this metric.
# Completed 82.41% of the slugs for this metric.
# Completed 83.33% of the slugs for this metric.
# Completed 84.26% of the slugs for this metric.
# Completed 85.19% of the slugs for this metric.
# Completed 86.11% of the slugs for this metric.
# Completed 87.04% of the slugs for this metric.
# Completed 87.96% of the slugs for this metric.
# Completed 88.89% of the slugs for this metric.
# Completed 89.81% of the slugs for this metric.
# Completed 90.74% of the slugs for this metric.
# Completed 91.67% of the slugs for this metric.
# Completed 92.59% of the slugs for this metric.
# Completed 93.52% of the slugs for this metric.
# Completed 94.44% of the slugs for this metric.
# Completed 95.37% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 96.3% of the slugs for this metric.
# Completed 97.22% of the slugs for this metric.
# Completed 98.15% of the slugs for this metric.
# Completed 99.07% of the slugs for this metric.
#
#
#
#
# dex_traders_to_defi_flow
# Completed 85.71% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 0.83% of the slugs for this metric.
# Completed 1.67% of the slugs for this metric.
# Completed 2.5% of the slugs for this metric.
# Completed 3.33% of the slugs for this metric.
# Completed 4.17% of the slugs for this metric.
# Completed 5.0% of the slugs for this metric.
# Completed 5.83% of the slugs for this metric.
# Completed 6.67% of the slugs for this metric.
# Completed 7.5% of the slugs for this metric.
# Completed 8.33% of the slugs for this metric.
# Completed 9.17% of the slugs for this metric.
# Completed 10.0% of the slugs for this metric.
# Completed 10.83% of the slugs for this metric.
# Completed 11.67% of the slugs for this metric.
# Completed 12.5% of the slugs for this metric.
# Completed 13.33% of the slugs for this metric.
# Completed 14.17% of the slugs for this metric.
# Completed 15.0% of the slugs for this metric.
# Completed 15.83% of the slugs for this metric.
# Completed 16.67% of the slugs for this metric.
# Completed 17.5% of the slugs for this metric.
# Completed 18.33% of the slugs for this metric.
# Completed 19.17% of the slugs for this metric.
# Completed 20.0% of the slugs for this metric.
# Completed 20.83% of the slugs for this metric.
# Completed 21.67% of the slugs for this metric.
# Completed 22.5% of the slugs for this metric.
# Completed 23.33% of the slugs for this metric.
# Completed 24.17% of the slugs for this metric.
# Completed 25.0% of the slugs for this metric.
# Completed 25.83% of the slugs for this metric.
# Completed 26.67% of the slugs for this metric.
# Completed 27.5% of the slugs for this metric.
# Completed 28.33% of the slugs for this metric.
# Completed 29.17% of the slugs for this metric.
# Completed 30.0% of the slugs for this metric.
# Completed 30.83% of the slugs for this metric.
# Completed 31.67% of the slugs for this metric.
# Completed 32.5% of the slugs for this metric.
# Completed 33.33% of the slugs for this metric.
# Completed 34.17% of the slugs for this metric.
# Completed 35.0% of the slugs for this metric.
# Completed 35.83% of the slugs for this metric.
# Completed 36.67% of the slugs for this metric.
# Completed 37.5% of the slugs for this metric.
# Completed 38.33% of the slugs for this metric.
# Completed 39.17% of the slugs for this metric.
# Completed 40.0% of the slugs for this metric.
# Completed 40.83% of the slugs for this metric.
# Completed 41.67% of the slugs for this metric.
# Completed 42.5% of the slugs for this metric.
# Completed 43.33% of the slugs for this metric.
# Completed 44.17% of the slugs for this metric.
# Completed 45.0% of the slugs for this metric.
# Completed 45.83% of the slugs for this metric.
# Completed 46.67% of the slugs for this metric.
# Completed 47.5% of the slugs for this metric.
# Completed 48.33% of the slugs for this metric.
# Completed 49.17% of the slugs for this metric.
# Completed 50.0% of the slugs for this metric.
# Completed 50.83% of the slugs for this metric.
# Completed 51.67% of the slugs for this metric.
# Completed 52.5% of the slugs for this metric.
# Completed 53.33% of the slugs for this metric.
# Completed 54.17% of the slugs for this metric.
# Completed 55.0% of the slugs for this metric.
# Completed 55.83% of the slugs for this metric.
# Completed 56.67% of the slugs for this metric.
# Completed 57.5% of the slugs for this metric.
# Completed 58.33% of the slugs for this metric.
# Completed 59.17% of the slugs for this metric.
# Completed 60.0% of the slugs for this metric.
# Completed 60.83% of the slugs for this metric.
# Completed 61.67% of the slugs for this metric.
# Completed 62.5% of the slugs for this metric.
# Completed 63.33% of the slugs for this metric.
# Completed 64.17% of the slugs for this metric.
# Completed 65.0% of the slugs for this metric.
# Completed 65.83% of the slugs for this metric.
# Completed 66.67% of the slugs for this metric.
# Completed 67.5% of the slugs for this metric.
# Completed 68.33% of the slugs for this metric.
# Completed 69.17% of the slugs for this metric.
# Completed 70.0% of the slugs for this metric.
# Completed 70.83% of the slugs for this metric.
# Completed 71.67% of the slugs for this metric.
# Completed 72.5% of the slugs for this metric.
# Completed 73.33% of the slugs for this metric.
# Completed 74.17% of the slugs for this metric.
# Completed 75.0% of the slugs for this metric.
# Completed 75.83% of the slugs for this metric.
# Completed 76.67% of the slugs for this metric.
# Completed 77.5% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 78.33% of the slugs for this metric.
# Completed 79.17% of the slugs for this metric.
# Completed 80.0% of the slugs for this metric.
# Completed 80.83% of the slugs for this metric.
# Completed 81.67% of the slugs for this metric.
# Completed 82.5% of the slugs for this metric.
# Completed 83.33% of the slugs for this metric.
# Completed 84.17% of the slugs for this metric.
# Completed 85.0% of the slugs for this metric.
# Completed 85.83% of the slugs for this metric.
# Completed 86.67% of the slugs for this metric.
# Completed 87.5% of the slugs for this metric.
# Completed 88.33% of the slugs for this metric.
# Completed 89.17% of the slugs for this metric.
# Completed 90.0% of the slugs for this metric.
# Completed 90.83% of the slugs for this metric.
# Completed 91.67% of the slugs for this metric.
# Completed 92.5% of the slugs for this metric.
# Completed 93.33% of the slugs for this metric.
# Completed 94.17% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 95.0% of the slugs for this metric.
# Completed 95.83% of the slugs for this metric.
# Completed 96.67% of the slugs for this metric.
# Completed 97.5% of the slugs for this metric.
# Completed 98.33% of the slugs for this metric.
# Completed 99.17% of the slugs for this metric.
#
#
#
#
# whale_defi_balance
# Completed 90.48% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 0.73% of the slugs for this metric.
# Completed 1.46% of the slugs for this metric.
# Completed 2.19% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 2.92% of the slugs for this metric.
# Completed 3.65% of the slugs for this metric.
# Completed 4.38% of the slugs for this metric.
# Completed 5.11% of the slugs for this metric.
# Completed 5.84% of the slugs for this metric.
# Completed 6.57% of the slugs for this metric.
# Completed 7.3% of the slugs for this metric.
# Completed 8.03% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 8.76% of the slugs for this metric.
# Completed 9.49% of the slugs for this metric.
# Completed 10.22% of the slugs for this metric.
# Completed 10.95% of the slugs for this metric.
# Completed 11.68% of the slugs for this metric.
# Completed 12.41% of the slugs for this metric.
# Completed 13.14% of the slugs for this metric.
# Completed 13.87% of the slugs for this metric.
# Completed 14.6% of the slugs for this metric.
# Completed 15.33% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 16.06% of the slugs for this metric.
# Completed 16.79% of the slugs for this metric.
# Completed 17.52% of the slugs for this metric.
# Completed 18.25% of the slugs for this metric.
# Completed 18.98% of the slugs for this metric.
# Completed 19.71% of the slugs for this metric.
# Completed 20.44% of the slugs for this metric.
# Completed 21.17% of the slugs for this metric.
# Completed 21.9% of the slugs for this metric.
# Completed 22.63% of the slugs for this metric.
# Completed 23.36% of the slugs for this metric.
# Completed 24.09% of the slugs for this metric.
# Completed 24.82% of the slugs for this metric.
# Completed 25.55% of the slugs for this metric.
# Completed 26.28% of the slugs for this metric.
# Completed 27.01% of the slugs for this metric.
# Completed 27.74% of the slugs for this metric.
# Completed 28.47% of the slugs for this metric.
# Completed 29.2% of the slugs for this metric.
# Completed 29.93% of the slugs for this metric.
# Completed 30.66% of the slugs for this metric.
# Completed 31.39% of the slugs for this metric.
# Completed 32.12% of the slugs for this metric.
# Completed 32.85% of the slugs for this metric.
# Completed 33.58% of the slugs for this metric.
# Completed 34.31% of the slugs for this metric.
# Completed 35.04% of the slugs for this metric.
# Completed 35.77% of the slugs for this metric.
# Completed 36.5% of the slugs for this metric.
# Completed 37.23% of the slugs for this metric.
# Completed 37.96% of the slugs for this metric.
# Completed 38.69% of the slugs for this metric.
# Completed 39.42% of the slugs for this metric.
# Completed 40.15% of the slugs for this metric.
# Completed 40.88% of the slugs for this metric.
# Completed 41.61% of the slugs for this metric.
# Completed 42.34% of the slugs for this metric.
# Completed 43.07% of the slugs for this metric.
# Completed 43.8% of the slugs for this metric.
# Completed 44.53% of the slugs for this metric.
# Completed 45.26% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 45.99% of the slugs for this metric.
# Completed 46.72% of the slugs for this metric.
# Completed 47.45% of the slugs for this metric.
# Completed 48.18% of the slugs for this metric.
# Completed 48.91% of the slugs for this metric.
# Completed 49.64% of the slugs for this metric.
# Completed 50.36% of the slugs for this metric.
# Completed 51.09% of the slugs for this metric.
# Completed 51.82% of the slugs for this metric.
# Completed 52.55% of the slugs for this metric.
# Completed 53.28% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 54.01% of the slugs for this metric.
# Completed 54.74% of the slugs for this metric.
# Completed 55.47% of the slugs for this metric.
# Completed 56.2% of the slugs for this metric.
# Completed 56.93% of the slugs for this metric.
# Completed 57.66% of the slugs for this metric.
# Completed 58.39% of the slugs for this metric.
# Completed 59.12% of the slugs for this metric.
# Completed 59.85% of the slugs for this metric.
# Completed 60.58% of the slugs for this metric.
# Completed 61.31% of the slugs for this metric.
# Completed 62.04% of the slugs for this metric.
# Completed 62.77% of the slugs for this metric.
# Completed 63.5% of the slugs for this metric.
# Completed 64.23% of the slugs for this metric.
# Completed 64.96% of the slugs for this metric.
# Completed 65.69% of the slugs for this metric.
# Completed 66.42% of the slugs for this metric.
# Completed 67.15% of the slugs for this metric.
# Completed 67.88% of the slugs for this metric.
# Completed 68.61% of the slugs for this metric.
# Completed 69.34% of the slugs for this metric.
# Completed 70.07% of the slugs for this metric.
# Completed 70.8% of the slugs for this metric.
# Completed 71.53% of the slugs for this metric.
# Completed 72.26% of the slugs for this metric.
# Completed 72.99% of the slugs for this metric.
# Completed 73.72% of the slugs for this metric.
# Completed 74.45% of the slugs for this metric.
# Completed 75.18% of the slugs for this metric.
# Completed 75.91% of the slugs for this metric.
# Completed 76.64% of the slugs for this metric.
# Completed 77.37% of the slugs for this metric.
# Completed 78.1% of the slugs for this metric.
# Completed 78.83% of the slugs for this metric.
# Completed 79.56% of the slugs for this metric.
# Completed 80.29% of the slugs for this metric.
# Completed 81.02% of the slugs for this metric.
# Completed 81.75% of the slugs for this metric.
# Completed 82.48% of the slugs for this metric.
# Completed 83.21% of the slugs for this metric.
# Completed 83.94% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 84.67% of the slugs for this metric.
# Completed 85.4% of the slugs for this metric.
# Completed 86.13% of the slugs for this metric.
# Completed 86.86% of the slugs for this metric.
# Completed 87.59% of the slugs for this metric.
# Completed 88.32% of the slugs for this metric.
# Completed 89.05% of the slugs for this metric.
# Completed 89.78% of the slugs for this metric.
# Completed 90.51% of the slugs for this metric.
# Completed 91.24% of the slugs for this metric.
# Completed 91.97% of the slugs for this metric.
# Completed 92.7% of the slugs for this metric.
# Completed 93.43% of the slugs for this metric.
# Completed 94.16% of the slugs for this metric.
# Completed 94.89% of the slugs for this metric.
# Completed 95.62% of the slugs for this metric.
# Completed 96.35% of the slugs for this metric.
# Completed 97.08% of the slugs for this metric.
# Completed 97.81% of the slugs for this metric.
# Completed 98.54% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 99.27% of the slugs for this metric.
#
#
#
#
# mvrv_usd_intraday
# Completed 95.24% of the metrics.
#
# Completed 0.0% of the slugs for this metric.
# Completed 1.75% of the slugs for this metric.
# Completed 3.51% of the slugs for this metric.
# Completed 5.26% of the slugs for this metric.
# Completed 7.02% of the slugs for this metric.
# Completed 8.77% of the slugs for this metric.
# Completed 10.53% of the slugs for this metric.
# Completed 12.28% of the slugs for this metric.
# Completed 14.04% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 15.79% of the slugs for this metric.
# Completed 17.54% of the slugs for this metric.
# Completed 19.3% of the slugs for this metric.
# Completed 21.05% of the slugs for this metric.
# Completed 22.81% of the slugs for this metric.
# Completed 24.56% of the slugs for this metric.
# Completed 26.32% of the slugs for this metric.
# Completed 28.07% of the slugs for this metric.
# Completed 29.82% of the slugs for this metric.
# Completed 31.58% of the slugs for this metric.
# Completed 33.33% of the slugs for this metric.
# api call is still running... let's kill it...
# Completed 35.09% of the slugs for this metric.
# Completed 36.84% of the slugs for this metric.
# Completed 38.6% of the slugs for this metric.
# Completed 40.35% of the slugs for this metric.
# Completed 42.11% of the slugs for this metric.
# Completed 43.86% of the slugs for this metric.
# Completed 45.61% of the slugs for this metric.
# Completed 47.37% of the slugs for this metric.
# Completed 49.12% of the slugs for this metric.
# Completed 50.88% of the slugs for this metric.
# Completed 52.63% of the slugs for this metric.
# Completed 54.39% of the slugs for this metric.
# Completed 56.14% of the slugs for this metric.
# Completed 57.89% of the slugs for this metric.
# Completed 59.65% of the slugs for this metric.
# Completed 61.4% of the slugs for this metric.
# Completed 63.16% of the slugs for this metric.
# Completed 64.91% of the slugs for this metric.
# Completed 66.67% of the slugs for this metric.
# Completed 68.42% of the slugs for this metric.
# Completed 70.18% of the slugs for this metric.
# Completed 71.93% of the slugs for this metric.
# Completed 73.68% of the slugs for this metric.
# Completed 75.44% of the slugs for this metric.
# Completed 77.19% of the slugs for this metric.
# Completed 78.95% of the slugs for this metric.
# Completed 80.7% of the slugs for this metric.
# Completed 82.46% of the slugs for this metric.
# Completed 84.21% of the slugs for this metric.
# Completed 85.96% of the slugs for this metric.
# Completed 87.72% of the slugs for this metric.
# Completed 89.47% of the slugs for this metric.
# Completed 91.23% of the slugs for this metric.
# Completed 92.98% of the slugs for this metric.
# Completed 94.74% of the slugs for this metric.
# Completed 96.49% of the slugs for this metric.
# Completed 98.25% of the slugs for this metric.

# %%
# CLEAN THE MACRO DATA

# Move over some data from the timeseries df to the macro df
temp_df = ts_df[['date', 'san_slug', 'stock_to_flow', 'traders_to_defi_flow', 'traders_defi_balance']]
ts_df = ts_df.drop(['stock_to_flow', 'traders_to_defi_flow', 'traders_defi_balance'], axis=1)
macro_df = macro_df.merge(temp_df,
                          on=['date', 'san_slug'],
                          how='outer',
                          validate='one_to_one')

# Form mcap weighted average variables
temp_df = macro_df[['date', 'san_slug', 'stock_to_flow', 'mvrv_usd_intraday', 'mcd_collat_ratio']]
temp_df = temp_df.dropna(how='all', subset=['stock_to_flow', 'mvrv_usd_intraday', 'mcd_collat_ratio'])
stf_tokens  = list(np.unique(temp_df[~temp_df.stock_to_flow.isnull()].san_slug.values))
mvrv_tokens = list(np.unique(temp_df[~temp_df.mvrv_usd_intraday.isnull()].san_slug.values))
mcd_tokens  = list(np.unique(temp_df[~temp_df.mcd_collat_ratio.isnull()].san_slug.values))
mcap_needed_tokens = list(np.unique(np.array(stf_tokens + mvrv_tokens + mcd_tokens + scd_tokens)))
temp_mcap_df = ts_df[ts_df.san_slug.isin(mcap_needed_tokens)][['date', 'san_slug', "marketcap_usd"]]
temp_df = temp_df.merge(temp_mcap_df,
                        on=['date', 'san_slug'],
                        how='inner',
                        validate='one_to_one')
for col in ['stock_to_flow', 'mvrv_usd_intraday', 'mcd_collat_ratio']:
    mcap_avg_temp_df = temp_df[['date', 'san_slug', col, 'marketcap_usd']]
    mcap_avg_temp_df = mcap_avg_temp_df.dropna()
    mcap_avg_temp_df['total_mcap'] = mcap_avg_temp_df.groupby('date')['marketcap_usd'].transform('sum')
    mcap_avg_temp_df['mcap_fraction'] = mcap_avg_temp_df.marketcap_usd / mcap_avg_temp_df.total_mcap
    mcap_avg_temp_df['temp'] = mcap_avg_temp_df.mcap_fraction * mcap_avg_temp_df[col]
    mcap_avg_temp_df = mcap_avg_temp_df.groupby('date')[['temp']].sum()
    mcap_avg_temp_df['san_slug'] = 'macro'
    mcap_avg_temp_df = mcap_avg_temp_df.reset_index()
    mcap_avg_temp_df = mcap_avg_temp_df.rename(columns = {'temp': ('santiment_token_mcap_avg_'+col)})
    macro_df = macro_df.merge(mcap_avg_temp_df,
                              on=['date', 'san_slug'],
                              how='outer',
                              validate='one_to_one')
    
# Form columns of dollar sum across tokens
sum_columns = ['cexes_to_dex_flow', 'exchanges_to_defi_flow', 'whale_to_defi_flow', 'dex_traders_to_defi_flow', 
               'whale_defi_balance', 'traders_to_defi_flow', 'traders_defi_balance']
for col in sum_columns: 
    temp_df = macro_df[['date', col]]
    temp_df = temp_df.groupby('date')[[col]].sum()
    temp_df = temp_df.rename(columns={col: 'santiment_token_sum_'+col})
    temp_df['san_slug'] = 'macro'
    temp_df = temp_df.reset_index()
    macro_df = macro_df.merge(temp_df,
                              on=['date', 'san_slug'],
                              how='outer',
                              validate='one_to_one')
    
# Form macro variables from column with just bitcoin and/or ethereum
columns = ['defi_total_value_locked_usd', 'nft_trade_volume_usd', 
           'nft_trades_count', 'nft_retail_trade_volume_usd', 
           'nft_whale_trade_volume_usd', 'nft_whale_trades_count', 
           'percent_of_whale_stablecoin_total_supply', 
           'average_fees_usd', 'fees_usd', 'eth2_roi', 'median_fees_usd',
           'miners_to_exchanges_flow', 'miners_exchange_balance', 
           'traders_to_defi_flow', 'traders_defi_balance', 
           'mvrv_usd_intraday', 'stock_to_flow']
for col in columns:
    temp_df = macro_df[['date', 'san_slug', col]]
    temp_df = temp_df.dropna()
    btc_eth_token = list(np.unique(temp_df.san_slug.values))
    if col in ['traders_defi_balance', 'traders_to_defi_flow',
               'mvrv_usd_intraday', 'stock_to_flow']:
        btc_eth_token = ['ethereum']
    for token in btc_eth_token:
        temp_token_df = temp_df[temp_df.san_slug == token]
        temp_token_df['san_slug'] = 'macro'
        temp_token_df = temp_token_df.rename(columns = {col: 'santiment_'+token+'_'+col})
        macro_df = macro_df.merge(temp_token_df,
                                  on=['date', 'san_slug'],
                                  how='outer',
                                  validate='one_to_one')

# Drop sum_columns and columns from macro_df
macro_df = macro_df.drop((sum_columns + columns), axis=1)
macro_df = macro_df.drop(['mcd_collat_ratio'], axis=1)

# Keep just the new rows
macro_df = macro_df[macro_df.san_slug == 'macro']
macro_df = macro_df.drop('san_slug', axis=1)

# Clean it up
macro_df = macro_df.reset_index(drop=True)
macro_df = macro_df.sort_values(by='date')

# %%
# SAVE DATA
ts_df.to_pickle('../3-data/raw/santiment_panel.pkl')
macro_df.to_pickle('../3-data/raw/santiment_macro.pkl')
cw_df.to_pickle('../3-data/raw/santiment_cw.pkl')
